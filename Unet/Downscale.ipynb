# %% [markdown]
# <a href="https://colab.research.google.com/github/shoujiali/Disaster-Impact-Estimation-Downscaling/blob/main/Downscale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Tweets raster

# %%
import os
import pandas as pd

file_path = '/content/drive/Shareddrives/TAMIDS Disaster Impact Estimation Prediction/Data/Yalong/GRIIDC data/with zip code/Copy of harvey_with_zipcode.csv'

df_harvey_griidc = pd.read_csv(file_path, low_memory=False)
print(f"Successfully loaded {len(df_harvey_griidc)} records from GRIIDC Harvey data.")
display(df_harvey_griidc.head())
# Out:
# Successfully loaded 209004 records from GRIIDC Harvey data.
#    possibly_sensitive lang                               geo  conversation_id  \
# 0               False   en  {'place_id': '9380bd69f4ecbe4b'}     9.084710e+17
# 1               False   en  {'place_id': '07d9ca6de0486000'}     9.084680e+17
# 2               False   en  {'place_id': '07d9ca6de0486000'}     9.084680e+17
# 3               False   en  {'place_id': '07d9ca6de0486000'}     9.084670e+17
# 4               False   en  {'place_id': '07d9ee7b96885000'}     9.084150e+17
#
#       author_id                                     public_metrics  \
# 0  3.116070e+09  {'retweet_count': 0, 'reply_count': 1, 'like_c...
# 1  2.828491e+09  {'retweet_count': 2, 'reply_count': 0, 'like_c...
# 2  2.828491e+09  {'retweet_count': 3, 'reply_count': 0, 'like_c...
# 3  2.828491e+09  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 4  1.232237e+08  {'retweet_count': 2, 'reply_count': 0, 'like_c...
#
#                                         media_urls            media_keys  \
# 0  https://pbs.twimg.com/media/DJuJw1HUMAAlniO.jpg  3_908471221829775360
# 1  https://pbs.twimg.com/media/DJuGzHuU8AAC7dk.jpg  3_908467962650095616
# 2  https://pbs.twimg.com/media/DJuGzKhUIAIEcUh.jpg  3_908467963400822786
# 3  https://pbs.twimg.com/media/DJuGeRaU8AAqU2X.jpg  3_908467604473311232
# 4  https://pbs.twimg.com/media/DJtyqmBVYAAlUuY.jpg  3_908445825931501568
#
#                  created_at  \
# 0  2017-09-14T23:23:17.000Z
# 1  2017-09-14T23:11:15.000Z
# 2  2017-09-14T23:09:56.000Z
# 3  2017-09-14T23:08:06.000Z
# 4  2017-09-14T19:41:12.000Z
#
#                                             entities reply_settings  \
# 0  {'hashtags': [{'start': 76, 'end': 83, 'tag': ...       everyone
# 1  {'hashtags': [{'start': 99, 'end': 117, 'tag':...       everyone
# 2  {'hashtags': [{'start': 86, 'end': 104, 'tag':...       everyone
# 3  {'hashtags': [{'start': 62, 'end': 80, 'tag': ...       everyone
# 4  {'urls': [{'start': 96, 'end': 119, 'url': 'ht...       everyone
#
#                                  context_annotations  \
# 0  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 1  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 2  [{'domain': {'id': '30', 'name': 'Entities [En...
# 3  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 4  [{'domain': {'id': '10', 'name': 'Person', 'de...
#
#                                                 text          place_id  \
# 0  Latest ozonesonde balloon flight from Socorro,...  9380bd69f4ecbe4b
# 1  Family and Faculty come together to recognize ...  07d9ca6de0486000
# 2  An awesome return of recognizing GOODER schola...  07d9ca6de0486000
# 3  Meet Mr. Alaniz one of the GOODER additions to...  07d9ca6de0486000
# 4  Have you already snagged this seasons ultimate...  07d9ee7b96885000
#
#                                                place  zip_code storm_name  \
# 0  {'type': 'Feature', 'bbox': [-106.3116372, 31....   79927.0     harvey
# 1  {'type': 'Feature', 'bbox': [-106.286140441894...   79927.0     harvey
# 2  {'type': 'Feature', 'bbox': [-106.286140441894...   79927.0     harvey
# 3  {'type': 'Feature', 'bbox': [-106.286140441894...   79927.0     harvey
# 4  {'type': 'Feature', 'bbox': [-106.320100614742...   79907.0     harvey
#
#                                           place_bbox
# 0  (-106.3116372, 31.601718, -106.210306, 31.689387)
# 1  (-106.28614044189453, 31.637645721435547, -106...
# 2  (-106.28614044189453, 31.637645721435547, -106...
# 3  (-106.28614044189453, 31.637645721435547, -106...
# 4  (-106.32010061474236, 31.67553212898165, -106....

# %%
import ast
import matplotlib.patches as mpatches
import pandas as pd

def _parse_bbox(s):
    """Return (lon_min, lat_min, lon_max, lat_max) or None."""
    try:
        # Check if it's a dict-like string from the 'place' column
        place_dict = ast.literal_eval(s)
        if isinstance(place_dict, dict) and 'bbox' in place_dict:
             bbox = place_dict['bbox']
             if len(bbox) == 4 and all(isinstance(coord, (int, float)) for coord in bbox):
                 return tuple(bbox)
             return None
    except (ValueError, SyntaxError, TypeError):
        pass

    # Fallback to the original string splitting logic provided by the user
    try:
        parts = [float(x.strip('()[] \'\"')) for x in str(s).split(',')]
        return tuple(parts) if len(parts) == 4 else None
    except Exception:
        return None

# Apply the parsing function to the 'place' column
_parsed = df_harvey_griidc['place'].apply(_parse_bbox)
_valid  = _parsed.notna()

# Filter out rows where bbox parsing failed
df_filtered_bbox = df_harvey_griidc[_valid].copy()

# Create columns for the coordinates
_coords = pd.DataFrame(_parsed[_valid].tolist(), columns=['lon_min','lat_min','lon_max','lat_max'], index=df_filtered_bbox.index)
df_filtered_bbox = pd.concat([df_filtered_bbox, _coords], axis=1)

df_filtered_bbox['parsed_bbox'] = _parsed[_valid]

print(f"Original GRIIDC records: {len(df_harvey_griidc)}")
print(f"Records with valid bounding box: {len(df_filtered_bbox)}")
display(df_filtered_bbox.head())
# Out:
# Original GRIIDC records: 209004
# Records with valid bounding box: 209004
#    possibly_sensitive lang                               geo  conversation_id  \
# 0               False   en  {'place_id': '9380bd69f4ecbe4b'}     9.084710e+17
# 1               False   en  {'place_id': '07d9ca6de0486000'}     9.084680e+17
# 2               False   en  {'place_id': '07d9ca6de0486000'}     9.084680e+17
# 3               False   en  {'place_id': '07d9ca6de0486000'}     9.084670e+17
# 4               False   en  {'place_id': '07d9ee7b96885000'}     9.084150e+17
#
#       author_id                                     public_metrics  \
# 0  3.116070e+09  {'retweet_count': 0, 'reply_count': 1, 'like_c...
# 1  2.828491e+09  {'retweet_count': 2, 'reply_count': 0, 'like_c...
# 2  2.828491e+09  {'retweet_count': 3, 'reply_count': 0, 'like_c...
# 3  2.828491e+09  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 4  1.232237e+08  {'retweet_count': 2, 'reply_count': 0, 'like_c...
#
#                                         media_urls            media_keys  \
# 0  https://pbs.twimg.com/media/DJuJw1HUMAAlniO.jpg  3_908471221829775360
# 1  https://pbs.twimg.com/media/DJuGzHuU8AAC7dk.jpg  3_908467962650095616
# 2  https://pbs.twimg.com/media/DJuGzKhUIAIEcUh.jpg  3_908467963400822786
# 3  https://pbs.twimg.com/media/DJuGeRaU8AAqU2X.jpg  3_908467604473311232
# 4  https://pbs.twimg.com/media/DJtyqmBVYAAlUuY.jpg  3_908445825931501568
#
#                  created_at  \
# 0  2017-09-14T23:23:17.000Z
# 1  2017-09-14T23:11:15.000Z
# 2  2017-09-14T23:09:56.000Z
# 3  2017-09-14T23:08:06.000Z
# 4  2017-09-14T19:41:12.000Z
#
#                                             entities  ...          place_id  \
# 0  {'hashtags': [{'start': 76, 'end': 83, 'tag': ...  ...  9380bd69f4ecbe4b
# 1  {'hashtags': [{'start': 99, 'end': 117, 'tag':...  ...  07d9ca6de0486000
# 2  {'hashtags': [{'start': 86, 'end': 104, 'tag':...  ...  07d9ca6de0486000
# 3  {'hashtags': [{'start': 62, 'end': 80, 'tag': ...  ...  07d9ca6de0486000
# 4  {'urls': [{'start': 96, 'end': 119, 'url': 'ht...  ...  07d9ee7b96885000
#
#                                                place zip_code storm_name  \
# 0  {'type': 'Feature', 'bbox': [-106.3116372, 31....  79927.0     harvey
# 1  {'type': 'Feature', 'bbox': [-106.286140441894...  79927.0     harvey
# 2  {'type': 'Feature', 'bbox': [-106.286140441894...  79927.0     harvey
# 3  {'type': 'Feature', 'bbox': [-106.286140441894...  79927.0     harvey
# 4  {'type': 'Feature', 'bbox': [-106.320100614742...  79907.0     harvey
#
#                                           place_bbox     lon_min    lat_min  \
# 0  (-106.3116372, 31.601718, -106.210306, 31.689387) -106.311637  31.601718
# 1  (-106.28614044189453, 31.637645721435547, -106... -106.286140  31.637646
# 2  (-106.28614044189453, 31.637645721435547, -106... -106.286140  31.637646
# 3  (-106.28614044189453, 31.637645721435547, -106... -106.286140  31.637646
# 4  (-106.32010061474236, 31.67553212898165, -106.... -106.320101  31.675532
#
#       lon_max    lat_max                                        parsed_bbox
# 0 -106.210306  31.689387  (-106.3116372, 31.601718, -106.210306, 31.689387)
# 1 -106.286140  31.637646  (-106.28614044189453, 31.637645721435547, -106...
# 2 -106.286140  31.637646  (-106.28614044189453, 31.637645721435547, -106...
# 3 -106.286140  31.637646  (-106.28614044189453, 31.637645721435547, -106...
# 4 -106.320101  31.675532  (-106.32010061474236, 31.67553212898165, -106....
#
# [5 rows x 23 columns]

# %%
import numpy as np
import pandas as pd
import rasterio
from rasterio.transform import from_origin

# Texas extent
TEXAS_LON_MIN, TEXAS_LON_MAX = -107.0, -93.0
TEXAS_LAT_MIN, TEXAS_LAT_MAX = 25.0, 37.0

GRID_SIZE = 0.025

# Raster dimensions
ncols = int(np.ceil((TEXAS_LON_MAX - TEXAS_LON_MIN) / GRID_SIZE))
nrows = int(np.ceil((TEXAS_LAT_MAX - TEXAS_LAT_MIN) / GRID_SIZE))

print("Rows:", nrows)
print("Columns:", ncols)
# Out:
# Rows: 480
# Columns: 560

# %%
bbox_df = df_filtered_bbox.copy()

coord_cols = ["lon_min", "lat_min", "lon_max", "lat_max"]

for col in coord_cols:
    bbox_df[col] = pd.to_numeric(
        bbox_df[col],
        errors="coerce"
    )

bbox_df = bbox_df.dropna(subset=coord_cols).copy()

# 修正坐标顺序异常
bbox_df = bbox_df[
    (bbox_df["lon_min"] <= bbox_df["lon_max"]) &
    (bbox_df["lat_min"] <= bbox_df["lat_max"])
].copy()

# 只保留与 Texas extent 相交的 bbox
bbox_df = bbox_df[
    ~(
        (bbox_df["lon_max"] < TEXAS_LON_MIN) |
        (bbox_df["lon_min"] > TEXAS_LON_MAX) |
        (bbox_df["lat_max"] < TEXAS_LAT_MIN) |
        (bbox_df["lat_min"] > TEXAS_LAT_MAX)
    )
].copy()

print("Valid tweet bounding boxes:", len(bbox_df))
# Out:
# Valid tweet bounding boxes: 209004

# %%
bbox_df["lon_min_clip"] = bbox_df["lon_min"].clip(
    lower=TEXAS_LON_MIN,
    upper=TEXAS_LON_MAX
)

bbox_df["lon_max_clip"] = bbox_df["lon_max"].clip(
    lower=TEXAS_LON_MIN,
    upper=TEXAS_LON_MAX
)

bbox_df["lat_min_clip"] = bbox_df["lat_min"].clip(
    lower=TEXAS_LAT_MIN,
    upper=TEXAS_LAT_MAX
)

bbox_df["lat_max_clip"] = bbox_df["lat_max"].clip(
    lower=TEXAS_LAT_MIN,
    upper=TEXAS_LAT_MAX
)

# %%
bbox_df["col_min"] = np.floor(
    (bbox_df["lon_min_clip"] - TEXAS_LON_MIN) / GRID_SIZE
).astype(int)

bbox_df["col_max"] = np.floor(
    (bbox_df["lon_max_clip"] - TEXAS_LON_MIN) / GRID_SIZE
).astype(int)

bbox_df["row_min"] = np.floor(
    (TEXAS_LAT_MAX - bbox_df["lat_max_clip"]) / GRID_SIZE
).astype(int)

bbox_df["row_max"] = np.floor(
    (TEXAS_LAT_MAX - bbox_df["lat_min_clip"]) / GRID_SIZE
).astype(int)

# %%
bbox_df["col_min"] = bbox_df["col_min"].clip(0, ncols - 1)
bbox_df["col_max"] = bbox_df["col_max"].clip(0, ncols - 1)

bbox_df["row_min"] = bbox_df["row_min"].clip(0, nrows - 1)
bbox_df["row_max"] = bbox_df["row_max"].clip(0, nrows - 1)

# %%
tweet_count_raster = np.zeros(
    (nrows, ncols),
    dtype=np.int32
)

for i, row in enumerate(bbox_df.itertuples(index=False)):

    tweet_count_raster[
        row.row_min : row.row_max + 1,
        row.col_min : row.col_max + 1
    ] += 1

    if (i + 1) % 10000 == 0:
        print(f"Processed {i + 1:,} / {len(bbox_df):,}")
# Out:
# Processed 10,000 / 209,004
# Processed 20,000 / 209,004
# Processed 30,000 / 209,004
# Processed 40,000 / 209,004
# Processed 50,000 / 209,004
# Processed 60,000 / 209,004
# Processed 70,000 / 209,004
# Processed 80,000 / 209,004
# Processed 90,000 / 209,004
# Processed 100,000 / 209,004
# Processed 110,000 / 209,004
# Processed 120,000 / 209,004
# Processed 130,000 / 209,004
# Processed 140,000 / 209,004
# Processed 150,000 / 209,004
# Processed 160,000 / 209,004
# Processed 170,000 / 209,004
# Processed 180,000 / 209,004
# Processed 190,000 / 209,004
# Processed 200,000 / 209,004

# %%
transform = from_origin(
    TEXAS_LON_MIN,
    TEXAS_LAT_MAX,
    GRID_SIZE,
    GRID_SIZE
)

output_tif = "texas_tweet_count_0025.tif"

with rasterio.open(
    output_tif,
    "w",
    driver="GTiff",
    height=nrows,
    width=ncols,
    count=1,
    dtype=tweet_count_raster.dtype,
    crs="EPSG:4326",
    transform=transform,
    nodata=0,
    compress="lzw"
) as dst:
    dst.write(tweet_count_raster, 1)

print("Saved:", output_tif)
# Out:
# Saved: texas_tweet_count_0025.tif

# %% [markdown]
# # fully supervised downscaling

# %% [markdown]
# ## DEM

# %%
## unzip *DEM*

import zipfile
import os

zip_path = "/content/drive/Shareddrives/TAMIDS Disaster Impact Estimation Prediction/Data/GIS_Data/USGSElevation.zip"
extract_folder = "dem_extract"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder)

print(os.listdir(extract_folder))
# Out:
# ['USGSEle20s']

# %%
import geopandas as gpd
import rasterio
from pathlib import Path
from shapely.geometry import box

units = gpd.read_file("/content/drive/MyDrive/Data/tl_2025_48_tract/tl_2025_48_tract.shp")

units = units.to_crs("EPSG:4269")

texas_boundary = units.dissolve().geometry.iloc[0]

dem_folder = Path("/content/dem_extract/USGSEle20s")

selected_files = []

for tif in dem_folder.rglob("*.tif"):
    with rasterio.open(tif) as src:
        b = src.bounds
        tile_box = box(b.left, b.bottom, b.right, b.top)

    if tile_box.intersects(texas_boundary):
        selected_files.append(str(tif))

print("Selected DEM tiles:", len(selected_files))
selected_files[:5]
# Out:
# Selected DEM tiles: 94
# ['/content/dem_extract/USGSEle20s/USGS_1_n31w097_20240229.tif',
#  '/content/dem_extract/USGSEle20s/USGS_1_n32w099_20250509.tif',
#  '/content/dem_extract/USGSEle20s/USGS_1_n32w104_20220721.tif',
#  '/content/dem_extract/USGSEle20s/USGS_1_n31w102_20201228.tif',
#  '/content/dem_extract/USGSEle20s/USGS_1_n35w102_20190916.tif']

# %%
import geopandas as gpd
from shapely.geometry import box
import rasterio

tiles = []

for tif in selected_files:

    with rasterio.open(tif) as src:
        b = src.bounds

    tiles.append(
        box(
            b.left,
            b.bottom,
            b.right,
            b.top
        )
    )

tiles_gdf = gpd.GeoDataFrame(
    geometry=tiles,
    crs="EPSG:4269"
)

ax = units.dissolve().boundary.plot(
    figsize=(8,8),
    color="black"
)

tiles_gdf.boundary.plot(
    ax=ax,
    color="red",
    linewidth=0.5
)
# Out:
# <Axes: >

# %% [markdown]
# ## dataset pro-processing

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class DoubleConv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.net(x)


class UNet(nn.Module):
    def __init__(self, in_channels):
        super().__init__()

        self.enc1 = DoubleConv(in_channels, 64)
        self.enc2 = DoubleConv(64, 128)
        self.enc3 = DoubleConv(128, 256)

        self.pool = nn.MaxPool2d(2)

        self.bottleneck = DoubleConv(256, 512)

        self.up3 = nn.ConvTranspose2d(512, 256, 2, stride=2)
        self.dec3 = DoubleConv(512, 256)

        self.up2 = nn.ConvTranspose2d(256, 128, 2, stride=2)
        self.dec2 = DoubleConv(256, 128)

        self.up1 = nn.ConvTranspose2d(128, 64, 2, stride=2)
        self.dec1 = DoubleConv(128, 64)

        self.out = nn.Conv2d(64, 1, 1)

    def forward(self, x):
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))

        b = self.bottleneck(self.pool(e3))

        d3 = self.up3(b)
        d3 = torch.cat([d3, e3], dim=1)
        d3 = self.dec3(d3)

        d2 = self.up2(d3)
        d2 = torch.cat([d2, e2], dim=1)
        d2 = self.dec2(d2)

        d1 = self.up1(d2)
        d1 = torch.cat([d1, e1], dim=1)
        d1 = self.dec1(d1)

        # water depth should be non-negative
        return F.relu(self.out(d1))

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import rasterio
from rasterio.enums import Resampling
from rasterio.warp import reproject
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader


OUTPUT_TIF = "unet_downscaled_0p1_to_0p025_waterdepth.tif"
# PATCH_SIZE = 160
PATCH_SIZE = 64
STRIDE = 32

BATCH_SIZE = 4
EPOCHS = 50
LEARNING_RATE = 1e-4
SMOOTHNESS_WEIGHT = 0.001

# %%
def resolve_raster_path(path_or_candidates):
    candidates = path_or_candidates
    if isinstance(candidates, (str, Path)):
        candidates = [candidates]

    checked = []
    for candidate in candidates:
        candidate = Path(candidate)
        checked.append(str(candidate))
        if candidate.exists():
            return candidate

    raise FileNotFoundError(
        "Could not find raster. Checked: " + ", ".join(checked)
    )


def read_raster(path_or_candidates):
    path = resolve_raster_path(path_or_candidates)
    with rasterio.open(path) as src:
        arr = src.read(1).astype("float32")
        profile = src.profile.copy()
        transform = src.transform
        crs = src.crs
        nodata = src.nodata

    if nodata is not None:
        arr[arr == nodata] = np.nan
    arr[arr <= -9999] = np.nan

    return arr, profile, transform, crs, nodata, path


def same_grid(src_shape, src_transform, src_crs, ref_shape, ref_transform, ref_crs):
    return (
        src_shape == ref_shape
        and src_crs == ref_crs
        and src_transform.almost_equals(ref_transform)
    )


def resample_to_match(
    src_array,
    src_transform,
    src_crs,
    ref_profile,
    ref_transform,
    ref_crs,
    resampling=Resampling.bilinear,
):
    ref_shape = (ref_profile["height"], ref_profile["width"])

    if same_grid(src_array.shape, src_transform, src_crs, ref_shape, ref_transform, ref_crs):
        return src_array.astype("float32")

    dst = np.full(ref_shape, np.nan, dtype="float32")
    reproject(
        source=src_array,
        destination=dst,
        src_transform=src_transform,
        src_crs=src_crs,
        src_nodata=np.nan,
        dst_transform=ref_transform,
        dst_crs=ref_crs,
        dst_nodata=np.nan,
        resampling=resampling,
    )
    dst[dst <= -9999] = np.nan
    return dst.astype("float32")

# %%
water_025, water_025_profile, water_025_transform, water_025_crs, water_025_nodata, water_025_path = read_raster(
    "/content/drive/Shareddrives/TAMIDS Disaster Impact Estimation Prediction/Data/Yuning/weather_grid_01deg/HGAC_ERA5wind_PRISMprecip_overlay_zoom/HGAC_0p025_grid_tifs/grid_waterDepth_0025.tif"
)
water_01, water_01_profile, water_01_transform, water_01_crs, water_01_nodata, water_01_path = read_raster(
    "/content/drive/Shareddrives/TAMIDS Disaster Impact Estimation Prediction/Data/Yuning/weather_grid_01deg/HGAC_ERA5wind_PRISMprecip_overlay_zoom/HGAC_0p025_grid_tifs/grid_waterDepth_01.tif"
)
precip_raw, precip_profile, precip_transform, precip_crs, precip_nodata, precip_path = read_raster(
    "/content/drive/Shareddrives/TAMIDS Disaster Impact Estimation Prediction/Data/Yuning/Grid_Texas/ERA5wind_PRISMprecip_Texas/Texas_0p025_grid_tifs/Texas_PRISM_cumulative_precip_mean_mm_0p025deg.tif"
)
wind_raw, wind_profile, wind_transform, wind_crs, wind_nodata, wind_path = read_raster(
    "/content/drive/Shareddrives/TAMIDS Disaster Impact Estimation Prediction/Data/Yuning/Grid_Texas/ERA5wind_PRISMprecip_Texas/Texas_0p025_grid_tifs/Texas_ERA5_max_wind_kts_0p025deg.tif"
)
# dem_raw, dem_profile, dem_transform, dem_crs, dem_nodata, dem_path = read_raster(
#     "/content/dem_extract/USGSEle20s/USGS_1_n29w096_20240229.tif"
# )

# %%
import numpy as np
import rasterio
from rasterio.warp import reproject
from rasterio.enums import Resampling

def build_dem_resampled_from_tiles(
    dem_paths,
    target_profile,
    target_transform,
    target_crs,
    resampling_method=Resampling.bilinear
):
    H = target_profile["height"]
    W = target_profile["width"]

    dem_sum = np.zeros((H, W), dtype="float32")
    dem_count = np.zeros((H, W), dtype="float32")

    for i, dem_path in enumerate(dem_paths, 1):
        print(f"[{i}/{len(dem_paths)}] {dem_path}")

        with rasterio.open(dem_path) as src:
            dem = src.read(1).astype("float32")

            src_nodata = src.nodata
            if src_nodata is not None:
                dem[dem == src_nodata] = np.nan

            temp = np.full((H, W), np.nan, dtype="float32")

            reproject(
                source=dem,
                destination=temp,
                src_transform=src.transform,
                src_crs=src.crs,
                dst_transform=target_transform,
                dst_crs=target_crs,
                src_nodata=np.nan,
                dst_nodata=np.nan,
                resampling=resampling_method
            )

            valid = np.isfinite(temp)

            dem_sum[valid] += temp[valid]
            dem_count[valid] += 1

    dem_resampled = np.full((H, W), np.nan, dtype="float32")

    valid = dem_count > 0
    dem_resampled[valid] = dem_sum[valid] / dem_count[valid]

    return dem_resampled

# %%
dem_resampled = build_dem_resampled_from_tiles(
    selected_files,
    water_025_profile,
    water_025_transform,
    water_025_crs
)

print(dem_resampled.shape)
print(np.nanmin(dem_resampled), np.nanmax(dem_resampled))
# Out:
# [1/94] /content/dem_extract/USGSEle20s/USGS_1_n31w097_20240229.tif
# [2/94] /content/dem_extract/USGSEle20s/USGS_1_n32w099_20250509.tif
# [3/94] /content/dem_extract/USGSEle20s/USGS_1_n32w104_20220721.tif
# [4/94] /content/dem_extract/USGSEle20s/USGS_1_n31w102_20201228.tif
# [5/94] /content/dem_extract/USGSEle20s/USGS_1_n35w102_20190916.tif
# [6/94] /content/dem_extract/USGSEle20s/USGS_1_n30w102_20201228.tif
# [7/94] /content/dem_extract/USGSEle20s/USGS_1_n34w103_20200214.tif
# [8/94] /content/dem_extract/USGSEle20s/USGS_1_n33w096_20250509.tif
# [9/94] /content/dem_extract/USGSEle20s/USGS_1_n36w102_20190916.tif
# [10/94] /content/dem_extract/USGSEle20s/USGS_1_n37w103_20210623.tif
# [11/94] /content/dem_extract/USGSEle20s/USGS_1_n27w099_20240925.tif
# [12/94] /content/dem_extract/USGSEle20s/USGS_1_n30w095_20240229.tif
# [13/94] /content/dem_extract/USGSEle20s/USGS_1_n34w102_20200214.tif
# [14/94] /content/dem_extract/USGSEle20s/USGS_1_n32w102_20201228.tif
# [15/94] /content/dem_extract/USGSEle20s/USGS_1_n30w096_20240229.tif
# [16/94] /content/dem_extract/USGSEle20s/USGS_1_n31w105_20210616.tif
# [17/94] /content/dem_extract/USGSEle20s/USGS_1_n33w099_20250509.tif
# [18/94] /content/dem_extract/USGSEle20s/USGS_1_n28w099_20211103.tif
# [19/94] /content/dem_extract/USGSEle20s/USGS_1_n32w107_20240416.tif
# [20/94] /content/dem_extract/USGSEle20s/USGS_1_n33w107_20240416.tif
# [21/94] /content/dem_extract/USGSEle20s/USGS_1_n35w104_20210624.tif
# [22/94] /content/dem_extract/USGSEle20s/USGS_1_n31w103_20201228.tif
# [23/94] /content/dem_extract/USGSEle20s/USGS_1_n37w102_20230613.tif
# [24/94] /content/dem_extract/USGSEle20s/USGS_1_n31w096_20240229.tif
# [25/94] /content/dem_extract/USGSEle20s/USGS_1_n32w106_20220721.tif
# [26/94] /content/dem_extract/USGSEle20s/USGS_1_n31w104_20201228.tif
# [27/94] /content/dem_extract/USGSEle20s/USGS_1_n30w098_20211103.tif
# [28/94] /content/dem_extract/USGSEle20s/USGS_1_n32w103_20211124.tif
# [29/94] /content/dem_extract/USGSEle20s/USGS_1_n36w103_20190916.tif
# [30/94] /content/dem_extract/USGSEle20s/USGS_1_n34w096_20250104.tif
# [31/94] /content/dem_extract/USGSEle20s/USGS_1_n31w101_20201228.tif
# [32/94] /content/dem_extract/USGSEle20s/USGS_1_n34w099_20250509.tif
# [33/94] /content/dem_extract/USGSEle20s/USGS_1_n36w104_20210624.tif
# [34/94] /content/dem_extract/USGSEle20s/USGS_1_n37w104_20210623.tif
# [35/94] /content/dem_extract/USGSEle20s/USGS_1_n31w099_20250509.tif
# [36/94] /content/dem_extract/USGSEle20s/USGS_1_n26w098_20240925.tif
# [37/94] /content/dem_extract/USGSEle20s/USGS_1_n30w099_20211103.tif
# [38/94] /content/dem_extract/USGSEle20s/USGS_1_n29w104_20201228.tif
# [39/94] /content/dem_extract/USGSEle20s/USGS_1_n27w100_20240925.tif
# [40/94] /content/dem_extract/USGSEle20s/USGS_1_n35w100_20250104.tif
# [41/94] /content/dem_extract/USGSEle20s/USGS_1_n30w105_20201228.tif
# [42/94] /content/dem_extract/USGSEle20s/USGS_1_n33w104_20220721.tif
# [43/94] /content/dem_extract/USGSEle20s/USGS_1_n32w105_20220721.tif
# [44/94] /content/dem_extract/USGSEle20s/USGS_1_n31w098_20250509.tif
# [45/94] /content/dem_extract/USGSEle20s/USGS_1_n29w098_20211103.tif
# [46/94] /content/dem_extract/USGSEle20s/USGS_1_n32w094_20211115.tif
# [47/94] /content/dem_extract/USGSEle20s/USGS_1_n28w097_20190730.tif
# [48/94] /content/dem_extract/USGSEle20s/USGS_1_n33w097_20250509.tif
# [49/94] /content/dem_extract/USGSEle20s/USGS_1_n32w100_20211103.tif
# [50/94] /content/dem_extract/USGSEle20s/USGS_1_n31w106_20210616.tif
# [51/94] /content/dem_extract/USGSEle20s/USGS_1_n27w098_20240925.tif
# [52/94] /content/dem_extract/USGSEle20s/USGS_1_n28w100_20201228.tif
# [53/94] /content/dem_extract/USGSEle20s/USGS_1_n34w100_20250718.tif
# [54/94] /content/dem_extract/USGSEle20s/USGS_1_n29w099_20211103.tif
# [55/94] /content/dem_extract/USGSEle20s/USGS_1_n34w098_20250509.tif
# [56/94] /content/dem_extract/USGSEle20s/USGS_1_n29w097_20240229.tif
# [57/94] /content/dem_extract/USGSEle20s/USGS_1_n30w097_20240229.tif
# [58/94] /content/dem_extract/USGSEle20s/USGS_1_n32w097_20211103.tif
# [59/94] /content/dem_extract/USGSEle20s/USGS_1_n31w094_20240229.tif
# [60/94] /content/dem_extract/USGSEle20s/USGS_1_n32w095_20211115.tif
# [61/94] /content/dem_extract/USGSEle20s/USGS_1_n34w101_20191104.tif
# [62/94] /content/dem_extract/USGSEle20s/USGS_1_n30w101_20201228.tif
# [63/94] /content/dem_extract/USGSEle20s/USGS_1_n34w104_20220721.tif
# [64/94] /content/dem_extract/USGSEle20s/USGS_1_n33w095_20250509.tif
# [65/94] /content/dem_extract/USGSEle20s/USGS_1_n36w101_20250104.tif
# [66/94] /content/dem_extract/USGSEle20s/USGS_1_n35w103_20190916.tif
# [67/94] /content/dem_extract/USGSEle20s/USGS_1_n33w105_20220721.tif
# [68/94] /content/dem_extract/USGSEle20s/USGS_1_n33w101_20250718.tif
# [69/94] /content/dem_extract/USGSEle20s/USGS_1_n33w106_20220721.tif
# [70/94] /content/dem_extract/USGSEle20s/USGS_1_n31w095_20240229.tif
# [71/94] /content/dem_extract/USGSEle20s/USGS_1_n33w100_20250718.tif
# [72/94] /content/dem_extract/USGSEle20s/USGS_1_n32w096_20240229.tif
# [73/94] /content/dem_extract/USGSEle20s/USGS_1_n33w103_20211124.tif
# [74/94] /content/dem_extract/USGSEle20s/USGS_1_n35w099_20250104.tif
# [75/94] /content/dem_extract/USGSEle20s/USGS_1_n32w101_20191029.tif
# [76/94] /content/dem_extract/USGSEle20s/USGS_1_n34w095_20211115.tif
# [77/94] /content/dem_extract/USGSEle20s/USGS_1_n35w098_20250104.tif
# [78/94] /content/dem_extract/USGSEle20s/USGS_1_n32w098_20250509.tif
# [79/94] /content/dem_extract/USGSEle20s/USGS_1_n33w098_20250509.tif
# [80/94] /content/dem_extract/USGSEle20s/USGS_1_n30w100_20211103.tif
# [81/94] /content/dem_extract/USGSEle20s/USGS_1_n28w098_20190730.tif
# [82/94] /content/dem_extract/USGSEle20s/USGS_1_n35w101_20190923.tif
# [83/94] /content/dem_extract/USGSEle20s/USGS_1_n29w096_20240229.tif
# [84/94] /content/dem_extract/USGSEle20s/USGS_1_n31w100_20211103.tif
# [85/94] /content/dem_extract/USGSEle20s/USGS_1_n37w101_20230613.tif
# [86/94] /content/dem_extract/USGSEle20s/USGS_1_n30w094_20240229.tif
# [87/94] /content/dem_extract/USGSEle20s/USGS_1_n34w097_20250104.tif
# [88/94] /content/dem_extract/USGSEle20s/USGS_1_n29w100_20201228.tif
# [89/94] /content/dem_extract/USGSEle20s/USGS_1_n37w100_20230613.tif
# [90/94] /content/dem_extract/USGSEle20s/USGS_1_n30w103_20201228.tif
# [91/94] /content/dem_extract/USGSEle20s/USGS_1_n33w102_20191211.tif
# [92/94] /content/dem_extract/USGSEle20s/USGS_1_n30w104_20201228.tif
# [93/94] /content/dem_extract/USGSEle20s/USGS_1_n36w100_20250104.tif
# [94/94] /content/dem_extract/USGSEle20s/USGS_1_n29w101_20201228.tif
# (427, 527)
# -0.59 2853.1384

# %%
tweet_raw, tweet_profile, tweet_transform, tweet_crs, tweet_nodata, tweet_path = read_raster("/content/texas_tweet_count_0025.tif")

# %%
water_01_up = resample_to_match(
    water_01,
    water_01_transform,
    water_01_crs,
    water_025_profile,
    water_025_transform,
    water_025_crs,
)
precip_025 = resample_to_match(
    precip_raw,
    precip_transform,
    precip_crs,
    water_025_profile,
    water_025_transform,
    water_025_crs,
)
wind_025 = resample_to_match(
    wind_raw,
    wind_transform,
    wind_crs,
    water_025_profile,
    water_025_transform,
    water_025_crs,
)
# dem_resampled = resample_to_match(
#     dem_raw,
#     dem_transform,
#     dem_crs,
#     water_025_profile,
#     water_025_transform,
#     water_025_crs,
# )

tweet_025 = resample_to_match(
    tweet_raw,
    tweet_transform,
    tweet_crs,
    water_025_profile,
    water_025_transform,
    water_025_crs,
)

# %%
def calculate_slope(dem_arr, pixel_size):
    dy, dx = np.gradient(dem_arr, pixel_size)
    slope = np.sqrt(dx**2 + dy**2)
    return slope.astype("float32")

slope_resampled = calculate_slope(dem_resampled, pixel_size=550)

# %%
def normalize(arr):
    mean = np.nanmean(arr)
    std = np.nanstd(arr)

    out = (arr - mean) / std
    out = np.nan_to_num(out, nan=0)

    return out.astype("float32")

# %%
water_01_norm = normalize(water_01_up)

precip_norm = normalize(precip_025)

wind_norm = normalize(wind_025)

tweets_norm = normalize(tweet_025)

dem_norm = normalize(dem_resampled)

slope_norm = normalize(slope_resampled)

# %%
print("water_01 path:", water_01_path)
print("water_025 path:", water_025_path)
print("precip path:", precip_path)
print("wind path:", wind_path)
# print("DEM path:", dem_path)
print("water_01 shape:", water_01.shape)
print("water_025 shape:", water_025.shape)
print("water_01_up shape:", water_01_up.shape)
print("precip shape:", precip_025.shape)
print("wind shape:", wind_025.shape)
print("DEM shape:", dem_norm.shape)
print("slope shape:", slope_resampled.shape)
# Out:
# water_01 path: /content/drive/Shareddrives/TAMIDS Disaster Impact Estimation Prediction/Data/Yuning/weather_grid_01deg/HGAC_ERA5wind_PRISMprecip_overlay_zoom/HGAC_0p025_grid_tifs/grid_waterDepth_01.tif
# water_025 path: /content/drive/Shareddrives/TAMIDS Disaster Impact Estimation Prediction/Data/Yuning/weather_grid_01deg/HGAC_ERA5wind_PRISMprecip_overlay_zoom/HGAC_0p025_grid_tifs/grid_waterDepth_0025.tif
# precip path: /content/drive/Shareddrives/TAMIDS Disaster Impact Estimation Prediction/Data/Yuning/Grid_Texas/ERA5wind_PRISMprecip_Texas/Texas_0p025_grid_tifs/Texas_PRISM_cumulative_precip_mean_mm_0p025deg.tif
# wind path: /content/drive/Shareddrives/TAMIDS Disaster Impact Estimation Prediction/Data/Yuning/Grid_Texas/ERA5wind_PRISMprecip_Texas/Texas_0p025_grid_tifs/Texas_ERA5_max_wind_kts_0p025deg.tif
# water_01 shape: (429, 528)
# water_025 shape: (427, 527)
# water_01_up shape: (427, 527)
# precip shape: (427, 527)
# wind shape: (427, 527)
# DEM shape: (427, 527)
# slope shape: (427, 527)

# %%
X_full = np.stack(
    [
        water_01_norm,
        precip_norm,
        wind_norm,
        dem_norm,
        slope_norm,
        tweets_norm
    ],
    axis=0,
).astype("float32")

y_full = water_025.astype("float32")
y_full[y_full <= -9999] = np.nan

for c in range(X_full.shape[0]):
    channel = X_full[c]
    channel[channel <= -9999] = np.nan
    finite_mask = np.isfinite(channel)

    if finite_mask.sum() == 0:
        print(f"channel {c} all NaN; filling with 0")
        X_full[c] = np.zeros_like(channel, dtype="float32")
        continue

    fill_value = np.nanmedian(channel)
    channel = np.nan_to_num(
        channel,
        nan=fill_value,
        posinf=fill_value,
        neginf=fill_value,
    )

    mean = channel.mean()
    std = channel.std()
    if std < 1e-6:
        print(f"channel {c} std too small; setting to zero")
        X_full[c] = np.zeros_like(channel, dtype="float32")
    else:
        X_full[c] = ((channel - mean) / std).astype("float32")

print("X_full shape:", X_full.shape)
print("y_full shape:", y_full.shape)
print("X nan:", np.isnan(X_full).sum())
print("X inf:", np.isinf(X_full).sum())
print("y nan:", np.isnan(y_full).sum())
print("y valid:", np.isfinite(y_full).sum())
# Out:
# X_full shape: (6, 427, 527)
# y_full shape: (427, 527)
# X nan: 0
# X inf: 0
# y nan: 118186
# y valid: 106843

# %%
def masked_mse_loss(pred, y):
    mask = torch.isfinite(pred) & torch.isfinite(y)

    if mask.sum() == 0:
        return None

    return F.mse_loss(pred[mask], y[mask])


def smoothness_loss(pred):
    dx = torch.abs(pred[:, :, :, 1:] - pred[:, :, :, :-1]).mean()
    dy = torch.abs(pred[:, :, 1:, :] - pred[:, :, :-1, :]).mean()
    return dx + dy

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print("device:", device)
print("cuda available:", torch.cuda.is_available())
# Out:
# device: cuda
# cuda available: True

# %% [markdown]
# ## 5 fold cross validation

# %%
class SupervisedFloodDataset(Dataset):
    def __init__(
        self,
        X_full,
        y_full,
        patch_size=PATCH_SIZE,
        stride=None,
        fold_map=None,
        val_fold=None,
        mode="train",
        drop_boundary=False
    ):
        self.X = X_full.astype("float32")
        self.y = y_full[np.newaxis, :, :].astype("float32")
        self.patch_size = patch_size
        self.stride = stride or patch_size
        self.samples = []

        _, height, width = self.X.shape

        total_patches = 0
        valid_y_patches = 0
        fold_kept = 0
        boundary_removed = 0

        for i in range(0, height - patch_size + 1, self.stride):
            for j in range(0, width - patch_size + 1, self.stride):
                total_patches += 1

                y_patch = self.y[:, i:i + patch_size, j:j + patch_size]

                if np.isfinite(y_patch).sum() == 0:
                    continue

                valid_y_patches += 1

                if fold_map is None or val_fold is None:
                    self.samples.append((i, j))
                    fold_kept += 1
                    continue

                patch_fold = fold_map[i:i + patch_size, j:j + patch_size]
                unique_folds = np.unique(patch_fold)

                if drop_boundary and len(unique_folds) != 1:
                    boundary_removed += 1
                    continue

                if drop_boundary:
                    patch_fold_id = unique_folds[0]
                else:
                    patch_fold_id = fold_map[
                        i + patch_size // 2,
                        j + patch_size // 2
                    ]

                if mode == "train" and patch_fold_id != val_fold:
                    self.samples.append((i, j))
                    fold_kept += 1

                elif mode == "val" and patch_fold_id == val_fold:
                    self.samples.append((i, j))
                    fold_kept += 1

        print("mode:", mode)
        print("total patches:", total_patches)
        print("valid y patches:", valid_y_patches)
        print("boundary removed:", boundary_removed)
        print("kept samples:", fold_kept)

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        i, j = self.samples[idx]

        X_patch = self.X[:, i:i+self.patch_size, j:j+self.patch_size]
        y_patch = self.y[:, i:i+self.patch_size, j:j+self.patch_size]

        return (
            torch.tensor(X_patch, dtype=torch.float32),
            torch.tensor(y_patch, dtype=torch.float32)
        )

# %%
def validate_model(model, val_loader, device):
    model.eval()

    all_pred = []
    all_true = []

    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            pred = model(X_batch)

            mask = torch.isfinite(pred) & torch.isfinite(y_batch)

            if mask.sum() == 0:
                continue

            all_pred.append(pred[mask].detach().cpu().numpy())
            all_true.append(y_batch[mask].detach().cpu().numpy())

    if len(all_pred) == 0:
        return np.nan, np.nan, np.nan

    y_pred = np.concatenate(all_pred)
    y_true = np.concatenate(all_true)

    errors = y_pred - y_true

    mae = np.mean(np.abs(errors))
    rmse = np.sqrt(np.mean(errors ** 2))

    ss_res = np.sum(errors ** 2)
    ss_tot = np.sum((y_true - np.mean(y_true)) ** 2)
    r2 = np.nan if ss_tot == 0 else 1 - ss_res / ss_tot

    return mae, rmse, r2

# %%
import numpy as np

_, H, W = X_full.shape

PATCH_SIZE = 64
STRIDE = 32
block_size = 64
n_folds = 5

flood_mask = np.isfinite(y_full) & (y_full > 0)

blocks = []

for i in range(0, H, block_size):
    for j in range(0, W, block_size):

        r0, r1 = i, min(i + block_size, H)
        c0, c1 = j, min(j + block_size, W)

        block_flood_count = np.sum(flood_mask[r0:r1, c0:c1])

        if block_flood_count == 0:
            continue

        blocks.append({
            "r0": r0,
            "r1": r1,
            "c0": c0,
            "c1": c1,
            "flood_count": block_flood_count
        })

print("Number of flood blocks:", len(blocks))
# Out:
# Number of flood blocks: 13

# %%
blocks = sorted(
    blocks,
    key=lambda x: x["flood_count"],
    reverse=True
)

fold_flood_counts = [0] * n_folds

fold_map = np.full((H, W), -1, dtype=np.int32)

for block in blocks:
    fold_id = np.argmin(fold_flood_counts)

    r0, r1 = block["r0"], block["r1"]
    c0, c1 = block["c0"], block["c1"]

    fold_map[r0:r1, c0:c1] = fold_id

    fold_flood_counts[fold_id] += block["flood_count"]

print("Flood pixels per fold:", fold_flood_counts)
# Out:
# Flood pixels per fold: [np.int64(2687), np.int64(1850), np.int64(1470), np.int64(963), np.int64(1097)]

# %%
for i in range(0, H, block_size):
    for j in range(0, W, block_size):

        r0, r1 = i, min(i + block_size, H)
        c0, c1 = j, min(j + block_size, W)

        if np.any(fold_map[r0:r1, c0:c1] != -1):
            continue

        fold_id = np.random.randint(0, n_folds)
        fold_map[r0:r1, c0:c1] = fold_id

# %%
for k in range(5):

    mask = fold_map == k
    y = y_full[mask]
    y = y[np.isfinite(y)]

    print("----------------")
    print("Fold", k)
    print("Pixels:", len(y))
    print("Min:", np.min(y))
    print("Max:", np.max(y))
    print("Mean:", np.mean(y))
    print("Std:", np.std(y))
    print("Flood pixels:", np.sum(y > 0))
# Out:
# ----------------
# Fold 0
# Pixels: 18639
# Min: 0.0
# Max: 8.0
# Mean: 0.19526315
# Std: 0.6898111
# Flood pixels: 2687
# ----------------
# Fold 1
# Pixels: 10852
# Min: 0.0
# Max: 19.932224
# Mean: 0.20487998
# Std: 0.5785824
# Flood pixels: 1850
# ----------------
# Fold 2
# Pixels: 31568
# Min: 0.0
# Max: 14.193421
# Mean: 0.0737996
# Std: 0.4748385
# Flood pixels: 1470
# ----------------
# Fold 3
# Pixels: 18076
# Min: 0.0
# Max: 3.943662
# Mean: 0.049207866
# Std: 0.29376602
# Flood pixels: 963
# ----------------
# Fold 4
# Pixels: 27708
# Min: 0.0
# Max: 27.984724
# Mean: 0.060789034
# Std: 0.62174845
# Flood pixels: 1097

# %%
plt.figure(figsize=(8, 6))
plt.imshow(fold_map, cmap="tab10")
plt.colorbar(label="Fold ID")
plt.title("2D Block Spatial 5-Fold Map")
plt.show()

# %%
for k in range(5):
    train_dataset = SupervisedFloodDataset(
        X_full=X_full,
        y_full=y_full,
        patch_size=PATCH_SIZE,
        stride=STRIDE,
        fold_map=fold_map,
        val_fold=k,
        mode="train",
        drop_boundary=False
    )

    val_dataset = SupervisedFloodDataset(
        X_full=X_full,
        y_full=y_full,
        patch_size=PATCH_SIZE,
        stride=STRIDE,
        fold_map=fold_map,
        val_fold=k,
        mode="val",
        drop_boundary=False
    )

    print(k, len(train_dataset), len(val_dataset))
# Out:
# mode: train
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 113
# mode: val
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 24
# 0 113 24
# mode: train
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 120
# mode: val
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 17
# 1 120 17
# mode: train
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 102
# mode: val
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 35
# 2 102 35
# mode: train
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 116
# mode: val
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 21
# 3 116 21
# mode: train
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 97
# mode: val
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 40
# 4 97 40

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# %%
# import pandas as pd

# fold_results = []

# for val_fold in range(5):
#     print("=" * 50)
#     print(f"Spatial Fold {val_fold + 1}/5")
#     print("=" * 50)

#     train_dataset = SupervisedFloodDataset(
#         X_full=X_full,
#         y_full=y_full,
#         patch_size=PATCH_SIZE,
#         stride=STRIDE,
#         fold_map=fold_map,
#         val_fold=val_fold,
#         mode="train",
#         drop_boundary=False
#     )

#     val_dataset = SupervisedFloodDataset(
#         X_full=X_full,
#         y_full=y_full,
#         patch_size=PATCH_SIZE,
#         stride=STRIDE,
#         fold_map=fold_map,
#         val_fold=val_fold,
#         mode="val",
#         drop_boundary=False
#     )

#     train_loader = DataLoader(
#         train_dataset,
#         batch_size=BATCH_SIZE,
#         shuffle=True
#     )

#     val_loader = DataLoader(
#         val_dataset,
#         batch_size=BATCH_SIZE,
#         shuffle=False
#     )

#     model = UNet(in_channels=X_full.shape[0]).to(device)

#     optimizer = torch.optim.Adam(
#         model.parameters(),
#         lr=LEARNING_RATE
#     )

#     best_val_rmse = np.inf
#     best_epoch = -1

#     for epoch in range(EPOCHS):
#         model.train()
#         train_losses = []

#         for X_batch, y_batch in train_loader:
#             X_batch = X_batch.to(device)
#             y_batch = y_batch.to(device)

#             optimizer.zero_grad()

#             pred = model(X_batch)

#             loss_main = masked_mse_loss(pred, y_batch)

#             if loss_main is None:
#                 continue

#             loss = loss_main + SMOOTHNESS_WEIGHT * smoothness_loss(pred)

#             loss.backward()
#             optimizer.step()

#             train_losses.append(loss.item())

#         train_loss = np.mean(train_losses) if len(train_losses) > 0 else np.nan

#         val_mae, val_rmse, val_r2 = validate_model(
#             model,
#             val_loader,
#             device
#         )

#         print(
#             f"Fold {val_fold+1}, "
#             f"Epoch {epoch+1}/{EPOCHS}, "
#             f"Train Loss: {train_loss:.6f}, "
#             f"Val MAE: {val_mae:.6f}, "
#             f"Val RMSE: {val_rmse:.6f}, "
#             f"Val R2: {val_r2:.6f}"
#         )

#         if np.isfinite(val_rmse) and val_rmse < best_val_rmse:
#             best_val_rmse = val_rmse
#             best_epoch = epoch + 1
#             best_val_mae = val_mae
#             best_val_r2 = val_r2

#     fold_results.append({
#         "fold": val_fold + 1,
#         "best_epoch": best_epoch,
#         "MAE": best_val_mae,
#         "RMSE": best_val_rmse,
#         "R2": best_val_r2
#     })
# Out:
# ==================================================
# Spatial Fold 1/5
# ==================================================
# mode: train
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 109
# mode: val
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 28
# Fold 1, Epoch 1/50, Train Loss: 0.184293, Val MAE: 0.126233, Val RMSE: 0.358587, Val R2: 0.629449
# Fold 1, Epoch 2/50, Train Loss: 0.114573, Val MAE: 0.092175, Val RMSE: 0.416157, Val R2: 0.500916
# Fold 1, Epoch 3/50, Train Loss: 0.095990, Val MAE: 0.106054, Val RMSE: 0.440008, Val R2: 0.442069
# Fold 1, Epoch 4/50, Train Loss: 0.064628, Val MAE: 0.077689, Val RMSE: 0.312832, Val R2: 0.717980
# Fold 1, Epoch 5/50, Train Loss: 0.069076, Val MAE: 0.050389, Val RMSE: 0.270949, Val R2: 0.788441
# Fold 1, Epoch 6/50, Train Loss: 0.057611, Val MAE: 0.054369, Val RMSE: 0.314181, Val R2: 0.715542
# Fold 1, Epoch 7/50, Train Loss: 0.037241, Val MAE: 0.059942, Val RMSE: 0.314653, Val R2: 0.714686
# Fold 1, Epoch 8/50, Train Loss: 0.031212, Val MAE: 0.054026, Val RMSE: 0.306772, Val R2: 0.728800
# Fold 1, Epoch 9/50, Train Loss: 0.030873, Val MAE: 0.057279, Val RMSE: 0.307413, Val R2: 0.727665
# Fold 1, Epoch 10/50, Train Loss: 0.053856, Val MAE: 0.044095, Val RMSE: 0.242798, Val R2: 0.830118
# Fold 1, Epoch 11/50, Train Loss: 0.022915, Val MAE: 0.056229, Val RMSE: 0.318689, Val R2: 0.707321
# Fold 1, Epoch 12/50, Train Loss: 0.026799, Val MAE: 0.046277, Val RMSE: 0.279323, Val R2: 0.775161
# Fold 1, Epoch 13/50, Train Loss: 0.020523, Val MAE: 0.045165, Val RMSE: 0.261449, Val R2: 0.803015
# Fold 1, Epoch 14/50, Train Loss: 0.025344, Val MAE: 0.049777, Val RMSE: 0.301846, Val R2: 0.737440
# Fold 1, Epoch 15/50, Train Loss: 0.020319, Val MAE: 0.047062, Val RMSE: 0.291610, Val R2: 0.754945
# Fold 1, Epoch 16/50, Train Loss: 0.027174, Val MAE: 0.042762, Val RMSE: 0.250028, Val R2: 0.819849
# Fold 1, Epoch 17/50, Train Loss: 0.020837, Val MAE: 0.048142, Val RMSE: 0.287705, Val R2: 0.761464
# Fold 1, Epoch 18/50, Train Loss: 0.014793, Val MAE: 0.043947, Val RMSE: 0.288996, Val R2: 0.759318
# Fold 1, Epoch 19/50, Train Loss: 0.011082, Val MAE: 0.043235, Val RMSE: 0.261750, Val R2: 0.802562
# Fold 1, Epoch 20/50, Train Loss: 0.010663, Val MAE: 0.039534, Val RMSE: 0.253632, Val R2: 0.814619
# Fold 1, Epoch 21/50, Train Loss: 0.008050, Val MAE: 0.050224, Val RMSE: 0.311372, Val R2: 0.720606
# Fold 1, Epoch 22/50, Train Loss: 0.008067, Val MAE: 0.046676, Val RMSE: 0.261145, Val R2: 0.803473
# Fold 1, Epoch 23/50, Train Loss: 0.009049, Val MAE: 0.040251, Val RMSE: 0.243040, Val R2: 0.829779
# Fold 1, Epoch 24/50, Train Loss: 0.015112, Val MAE: 0.050304, Val RMSE: 0.304943, Val R2: 0.732024
# Fold 1, Epoch 25/50, Train Loss: 0.012436, Val MAE: 0.041880, Val RMSE: 0.272686, Val R2: 0.785719
# Fold 1, Epoch 26/50, Train Loss: 0.009219, Val MAE: 0.042218, Val RMSE: 0.273554, Val R2: 0.784353
# Fold 1, Epoch 27/50, Train Loss: 0.008564, Val MAE: 0.039887, Val RMSE: 0.240098, Val R2: 0.833875
# Fold 1, Epoch 28/50, Train Loss: 0.007534, Val MAE: 0.043114, Val RMSE: 0.268361, Val R2: 0.792462
# Fold 1, Epoch 29/50, Train Loss: 0.026279, Val MAE: 0.044350, Val RMSE: 0.298644, Val R2: 0.742981
# Fold 1, Epoch 30/50, Train Loss: 0.018999, Val MAE: 0.040158, Val RMSE: 0.262459, Val R2: 0.801490
# Fold 1, Epoch 31/50, Train Loss: 0.009257, Val MAE: 0.039920, Val RMSE: 0.246927, Val R2: 0.824290
# Fold 1, Epoch 32/50, Train Loss: 0.007901, Val MAE: 0.040563, Val RMSE: 0.241809, Val R2: 0.831498
# Fold 1, Epoch 33/50, Train Loss: 0.052643, Val MAE: 0.038143, Val RMSE: 0.221949, Val R2: 0.858040
# Fold 1, Epoch 34/50, Train Loss: 0.008882, Val MAE: 0.050861, Val RMSE: 0.327094, Val R2: 0.691678
# Fold 1, Epoch 35/50, Train Loss: 0.008347, Val MAE: 0.047540, Val RMSE: 0.288285, Val R2: 0.760502
# Fold 1, Epoch 36/50, Train Loss: 0.005294, Val MAE: 0.038074, Val RMSE: 0.241299, Val R2: 0.832209
# Fold 1, Epoch 37/50, Train Loss: 0.006122, Val MAE: 0.040784, Val RMSE: 0.260458, Val R2: 0.804506
# Fold 1, Epoch 38/50, Train Loss: 0.019549, Val MAE: 0.039786, Val RMSE: 0.244517, Val R2: 0.827703
# Fold 1, Epoch 39/50, Train Loss: 0.013587, Val MAE: 0.064739, Val RMSE: 0.471912, Val R2: 0.358228
# Fold 1, Epoch 40/50, Train Loss: 0.013936, Val MAE: 0.046420, Val RMSE: 0.298128, Val R2: 0.743868
# Fold 1, Epoch 41/50, Train Loss: 0.016568, Val MAE: 0.042081, Val RMSE: 0.318690, Val R2: 0.707319
# Fold 1, Epoch 42/50, Train Loss: 0.015199, Val MAE: 0.073543, Val RMSE: 0.403852, Val R2: 0.529995
# Fold 1, Epoch 43/50, Train Loss: 0.011427, Val MAE: 0.092547, Val RMSE: 0.643783, Val R2: -0.194366
# Fold 1, Epoch 44/50, Train Loss: 0.018315, Val MAE: 0.062880, Val RMSE: 0.360642, Val R2: 0.625190
# Fold 1, Epoch 45/50, Train Loss: 0.021992, Val MAE: 0.036416, Val RMSE: 0.221879, Val R2: 0.858129
# Fold 1, Epoch 46/50, Train Loss: 0.006202, Val MAE: 0.037667, Val RMSE: 0.241149, Val R2: 0.832417
# Fold 1, Epoch 47/50, Train Loss: 0.008348, Val MAE: 0.043746, Val RMSE: 0.312306, Val R2: 0.718927
# Fold 1, Epoch 48/50, Train Loss: 0.007661, Val MAE: 0.040796, Val RMSE: 0.239618, Val R2: 0.834538
# Fold 1, Epoch 49/50, Train Loss: 0.005456, Val MAE: 0.040290, Val RMSE: 0.349534, Val R2: 0.647922
# Fold 1, Epoch 50/50, Train Loss: 0.004656, Val MAE: 0.039781, Val RMSE: 0.262492, Val R2: 0.801440
# ==================================================
# Spatial Fold 2/5
# ==================================================
# mode: train
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 118
# mode: val
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 19
# Fold 2, Epoch 1/50, Train Loss: 0.131619, Val MAE: 0.132093, Val RMSE: 0.483345, Val R2: 0.663136
# Fold 2, Epoch 2/50, Train Loss: 0.088045, Val MAE: 0.178737, Val RMSE: 0.607948, Val R2: 0.467068
# Fold 2, Epoch 3/50, Train Loss: 0.060678, Val MAE: 0.124373, Val RMSE: 0.449080, Val R2: 0.709206
# Fold 2, Epoch 4/50, Train Loss: 0.053385, Val MAE: 0.131012, Val RMSE: 0.469614, Val R2: 0.682004
# Fold 2, Epoch 5/50, Train Loss: 0.039194, Val MAE: 0.125751, Val RMSE: 0.447343, Val R2: 0.711451
# Fold 2, Epoch 6/50, Train Loss: 0.041130, Val MAE: 0.114895, Val RMSE: 0.408100, Val R2: 0.759855
# Fold 2, Epoch 7/50, Train Loss: 0.033639, Val MAE: 0.163575, Val RMSE: 0.584050, Val R2: 0.508143
# Fold 2, Epoch 8/50, Train Loss: 0.042787, Val MAE: 0.227990, Val RMSE: 0.763130, Val R2: 0.160276
# Fold 2, Epoch 9/50, Train Loss: 0.031542, Val MAE: 0.128344, Val RMSE: 0.440968, Val R2: 0.719615
# Fold 2, Epoch 10/50, Train Loss: 0.025879, Val MAE: 0.174789, Val RMSE: 0.564030, Val R2: 0.541285
# Fold 2, Epoch 11/50, Train Loss: 0.020305, Val MAE: 0.103566, Val RMSE: 0.371923, Val R2: 0.800544
# Fold 2, Epoch 12/50, Train Loss: 0.026448, Val MAE: 0.110996, Val RMSE: 0.404785, Val R2: 0.763741
# Fold 2, Epoch 13/50, Train Loss: 0.020499, Val MAE: 0.150750, Val RMSE: 0.517882, Val R2: 0.613276
# Fold 2, Epoch 14/50, Train Loss: 0.013045, Val MAE: 0.116414, Val RMSE: 0.445094, Val R2: 0.714344
# Fold 2, Epoch 15/50, Train Loss: 0.023356, Val MAE: 0.109969, Val RMSE: 0.386829, Val R2: 0.784237
# Fold 2, Epoch 16/50, Train Loss: 0.024037, Val MAE: 0.153062, Val RMSE: 0.562283, Val R2: 0.544121
# Fold 2, Epoch 17/50, Train Loss: 0.016711, Val MAE: 0.099430, Val RMSE: 0.363022, Val R2: 0.809977
# Fold 2, Epoch 18/50, Train Loss: 0.012762, Val MAE: 0.097681, Val RMSE: 0.347836, Val R2: 0.825543
# Fold 2, Epoch 19/50, Train Loss: 0.007601, Val MAE: 0.105573, Val RMSE: 0.389735, Val R2: 0.780983
# Fold 2, Epoch 20/50, Train Loss: 0.011155, Val MAE: 0.122036, Val RMSE: 0.446535, Val R2: 0.712492
# Fold 2, Epoch 21/50, Train Loss: 0.018671, Val MAE: 0.107757, Val RMSE: 0.430610, Val R2: 0.732633
# Fold 2, Epoch 22/50, Train Loss: 0.012928, Val MAE: 0.127686, Val RMSE: 0.468355, Val R2: 0.683707
# Fold 2, Epoch 23/50, Train Loss: 0.009876, Val MAE: 0.103578, Val RMSE: 0.378854, Val R2: 0.793042
# Fold 2, Epoch 24/50, Train Loss: 0.009714, Val MAE: 0.106199, Val RMSE: 0.388683, Val R2: 0.782164
# Fold 2, Epoch 25/50, Train Loss: 0.006727, Val MAE: 0.099687, Val RMSE: 0.360361, Val R2: 0.812753
# Fold 2, Epoch 26/50, Train Loss: 0.005784, Val MAE: 0.093653, Val RMSE: 0.335633, Val R2: 0.837569
# Fold 2, Epoch 27/50, Train Loss: 0.004424, Val MAE: 0.091614, Val RMSE: 0.346012, Val R2: 0.827368
# Fold 2, Epoch 28/50, Train Loss: 0.006132, Val MAE: 0.130413, Val RMSE: 0.450698, Val R2: 0.707106
# Fold 2, Epoch 29/50, Train Loss: 0.006281, Val MAE: 0.100104, Val RMSE: 0.398764, Val R2: 0.770718
# Fold 2, Epoch 30/50, Train Loss: 0.005786, Val MAE: 0.085817, Val RMSE: 0.320679, Val R2: 0.851720
# Fold 2, Epoch 31/50, Train Loss: 0.004346, Val MAE: 0.099126, Val RMSE: 0.357746, Val R2: 0.815461
# Fold 2, Epoch 32/50, Train Loss: 0.003595, Val MAE: 0.088775, Val RMSE: 0.330908, Val R2: 0.842110
# Fold 2, Epoch 33/50, Train Loss: 0.004673, Val MAE: 0.087557, Val RMSE: 0.348816, Val R2: 0.824558
# Fold 2, Epoch 34/50, Train Loss: 0.004868, Val MAE: 0.091431, Val RMSE: 0.330017, Val R2: 0.842960
# Fold 2, Epoch 35/50, Train Loss: 0.003229, Val MAE: 0.086285, Val RMSE: 0.333881, Val R2: 0.839261
# Fold 2, Epoch 36/50, Train Loss: 0.003085, Val MAE: 0.094803, Val RMSE: 0.339826, Val R2: 0.833485
# Fold 2, Epoch 37/50, Train Loss: 0.004209, Val MAE: 0.085093, Val RMSE: 0.321323, Val R2: 0.851124
# Fold 2, Epoch 38/50, Train Loss: 0.004204, Val MAE: 0.098977, Val RMSE: 0.359695, Val R2: 0.813444
# Fold 2, Epoch 39/50, Train Loss: 0.005655, Val MAE: 0.128706, Val RMSE: 0.444199, Val R2: 0.715492
# Fold 2, Epoch 40/50, Train Loss: 0.004376, Val MAE: 0.094210, Val RMSE: 0.348440, Val R2: 0.824937
# Fold 2, Epoch 41/50, Train Loss: 0.011385, Val MAE: 0.087869, Val RMSE: 0.327145, Val R2: 0.845681
# Fold 2, Epoch 42/50, Train Loss: 0.004008, Val MAE: 0.097034, Val RMSE: 0.336596, Val R2: 0.836636
# Fold 2, Epoch 43/50, Train Loss: 0.006150, Val MAE: 0.138933, Val RMSE: 0.459282, Val R2: 0.695843
# Fold 2, Epoch 44/50, Train Loss: 0.009547, Val MAE: 0.099979, Val RMSE: 0.392502, Val R2: 0.777862
# Fold 2, Epoch 45/50, Train Loss: 0.008277, Val MAE: 0.098918, Val RMSE: 0.397713, Val R2: 0.771925
# Fold 2, Epoch 46/50, Train Loss: 0.011618, Val MAE: 0.088940, Val RMSE: 0.331693, Val R2: 0.841360
# Fold 2, Epoch 47/50, Train Loss: 0.005710, Val MAE: 0.084072, Val RMSE: 0.336421, Val R2: 0.836806
# Fold 2, Epoch 48/50, Train Loss: 0.006143, Val MAE: 0.127565, Val RMSE: 0.431529, Val R2: 0.731491
# Fold 2, Epoch 49/50, Train Loss: 0.005786, Val MAE: 0.086055, Val RMSE: 0.350441, Val R2: 0.822920
# Fold 2, Epoch 50/50, Train Loss: 0.005078, Val MAE: 0.105255, Val RMSE: 0.394332, Val R2: 0.775786
# ==================================================
# Spatial Fold 3/5
# ==================================================
# mode: train
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 107
# mode: val
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 30
# Fold 3, Epoch 1/50, Train Loss: 0.197091, Val MAE: 0.032211, Val RMSE: 0.312823, Val R2: 0.521113
# Fold 3, Epoch 2/50, Train Loss: 0.115364, Val MAE: 0.050984, Val RMSE: 0.336617, Val R2: 0.445492
# Fold 3, Epoch 3/50, Train Loss: 0.083605, Val MAE: 0.030411, Val RMSE: 0.255232, Val R2: 0.681210
# Fold 3, Epoch 4/50, Train Loss: 0.068648, Val MAE: 0.025794, Val RMSE: 0.208927, Val R2: 0.786388
# Fold 3, Epoch 5/50, Train Loss: 0.049090, Val MAE: 0.023748, Val RMSE: 0.207103, Val R2: 0.790102
# Fold 3, Epoch 6/50, Train Loss: 0.062117, Val MAE: 0.024513, Val RMSE: 0.221496, Val R2: 0.759914
# Fold 3, Epoch 7/50, Train Loss: 0.044815, Val MAE: 0.023633, Val RMSE: 0.219475, Val R2: 0.764274
# Fold 3, Epoch 8/50, Train Loss: 0.033597, Val MAE: 0.022118, Val RMSE: 0.189444, Val R2: 0.824371
# Fold 3, Epoch 9/50, Train Loss: 0.048729, Val MAE: 0.023071, Val RMSE: 0.216851, Val R2: 0.769878
# Fold 3, Epoch 10/50, Train Loss: 0.027524, Val MAE: 0.021261, Val RMSE: 0.193794, Val R2: 0.816213
# Fold 3, Epoch 11/50, Train Loss: 0.018900, Val MAE: 0.025277, Val RMSE: 0.201304, Val R2: 0.801692
# Fold 3, Epoch 12/50, Train Loss: 0.021063, Val MAE: 0.020715, Val RMSE: 0.178619, Val R2: 0.843868
# Fold 3, Epoch 13/50, Train Loss: 0.018475, Val MAE: 0.022463, Val RMSE: 0.254127, Val R2: 0.683963
# Fold 3, Epoch 14/50, Train Loss: 0.020153, Val MAE: 0.019417, Val RMSE: 0.164718, Val R2: 0.867225
# Fold 3, Epoch 15/50, Train Loss: 0.013989, Val MAE: 0.019554, Val RMSE: 0.163681, Val R2: 0.868891
# Fold 3, Epoch 16/50, Train Loss: 0.029630, Val MAE: 0.044281, Val RMSE: 0.304912, Val R2: 0.545027
# Fold 3, Epoch 17/50, Train Loss: 0.021897, Val MAE: 0.021599, Val RMSE: 0.187259, Val R2: 0.828398
# Fold 3, Epoch 18/50, Train Loss: 0.016185, Val MAE: 0.020239, Val RMSE: 0.183960, Val R2: 0.834391
# Fold 3, Epoch 19/50, Train Loss: 0.015937, Val MAE: 0.021335, Val RMSE: 0.184191, Val R2: 0.833975
# Fold 3, Epoch 20/50, Train Loss: 0.011124, Val MAE: 0.024699, Val RMSE: 0.184234, Val R2: 0.833899
# Fold 3, Epoch 21/50, Train Loss: 0.009712, Val MAE: 0.019651, Val RMSE: 0.164456, Val R2: 0.867646
# Fold 3, Epoch 22/50, Train Loss: 0.008577, Val MAE: 0.019565, Val RMSE: 0.170392, Val R2: 0.857919
# Fold 3, Epoch 23/50, Train Loss: 0.011280, Val MAE: 0.015999, Val RMSE: 0.151370, Val R2: 0.887871
# Fold 3, Epoch 24/50, Train Loss: 0.011661, Val MAE: 0.017061, Val RMSE: 0.154374, Val R2: 0.883376
# Fold 3, Epoch 25/50, Train Loss: 0.007081, Val MAE: 0.019241, Val RMSE: 0.202828, Val R2: 0.798678
# Fold 3, Epoch 26/50, Train Loss: 0.010077, Val MAE: 0.017163, Val RMSE: 0.153042, Val R2: 0.885381
# Fold 3, Epoch 27/50, Train Loss: 0.009552, Val MAE: 0.017739, Val RMSE: 0.148629, Val R2: 0.891896
# Fold 3, Epoch 28/50, Train Loss: 0.007641, Val MAE: 0.016521, Val RMSE: 0.144604, Val R2: 0.897671
# Fold 3, Epoch 29/50, Train Loss: 0.009564, Val MAE: 0.017339, Val RMSE: 0.152556, Val R2: 0.886107
# Fold 3, Epoch 30/50, Train Loss: 0.007832, Val MAE: 0.017536, Val RMSE: 0.157207, Val R2: 0.879058
# Fold 3, Epoch 31/50, Train Loss: 0.012548, Val MAE: 0.019457, Val RMSE: 0.202959, Val R2: 0.798417
# Fold 3, Epoch 32/50, Train Loss: 0.008016, Val MAE: 0.016208, Val RMSE: 0.151889, Val R2: 0.887102
# Fold 3, Epoch 33/50, Train Loss: 0.007319, Val MAE: 0.016557, Val RMSE: 0.145553, Val R2: 0.896324
# Fold 3, Epoch 34/50, Train Loss: 0.005753, Val MAE: 0.018695, Val RMSE: 0.164504, Val R2: 0.867569
# Fold 3, Epoch 35/50, Train Loss: 0.006561, Val MAE: 0.024212, Val RMSE: 0.254198, Val R2: 0.683786
# Fold 3, Epoch 36/50, Train Loss: 0.005567, Val MAE: 0.016500, Val RMSE: 0.142141, Val R2: 0.901128
# Fold 3, Epoch 37/50, Train Loss: 0.009269, Val MAE: 0.020759, Val RMSE: 0.189693, Val R2: 0.823909
# Fold 3, Epoch 38/50, Train Loss: 0.006897, Val MAE: 0.018563, Val RMSE: 0.152927, Val R2: 0.885553
# Fold 3, Epoch 39/50, Train Loss: 0.004700, Val MAE: 0.016447, Val RMSE: 0.141574, Val R2: 0.901915
# Fold 3, Epoch 40/50, Train Loss: 0.005506, Val MAE: 0.017360, Val RMSE: 0.157316, Val R2: 0.878889
# Fold 3, Epoch 41/50, Train Loss: 0.005187, Val MAE: 0.015888, Val RMSE: 0.143787, Val R2: 0.898824
# Fold 3, Epoch 42/50, Train Loss: 0.003910, Val MAE: 0.016249, Val RMSE: 0.145063, Val R2: 0.897020
# Fold 3, Epoch 43/50, Train Loss: 0.004740, Val MAE: 0.016121, Val RMSE: 0.140909, Val R2: 0.902835
# Fold 3, Epoch 44/50, Train Loss: 0.005075, Val MAE: 0.016849, Val RMSE: 0.149526, Val R2: 0.890586
# Fold 3, Epoch 45/50, Train Loss: 0.003903, Val MAE: 0.017118, Val RMSE: 0.154634, Val R2: 0.882984
# Fold 3, Epoch 46/50, Train Loss: 0.004946, Val MAE: 0.015897, Val RMSE: 0.144636, Val R2: 0.897626
# Fold 3, Epoch 47/50, Train Loss: 0.004762, Val MAE: 0.017337, Val RMSE: 0.148223, Val R2: 0.892486
# Fold 3, Epoch 48/50, Train Loss: 0.002767, Val MAE: 0.016135, Val RMSE: 0.142962, Val R2: 0.899982
# Fold 3, Epoch 49/50, Train Loss: 0.002746, Val MAE: 0.017046, Val RMSE: 0.148808, Val R2: 0.891635
# Fold 3, Epoch 50/50, Train Loss: 0.004539, Val MAE: 0.017652, Val RMSE: 0.149049, Val R2: 0.891284
# ==================================================
# Spatial Fold 4/5
# ==================================================
# mode: train
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 106
# mode: val
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 31
# Fold 4, Epoch 1/50, Train Loss: 0.239881, Val MAE: 0.006658, Val RMSE: 0.079252, Val R2: 0.407751
# Fold 4, Epoch 2/50, Train Loss: 0.097670, Val MAE: 0.006827, Val RMSE: 0.072012, Val R2: 0.511011
# Fold 4, Epoch 3/50, Train Loss: 0.101472, Val MAE: 0.005376, Val RMSE: 0.060285, Val R2: 0.657307
# Fold 4, Epoch 4/50, Train Loss: 0.087249, Val MAE: 0.005640, Val RMSE: 0.058812, Val R2: 0.673850
# Fold 4, Epoch 5/50, Train Loss: 0.052150, Val MAE: 0.007646, Val RMSE: 0.064192, Val R2: 0.611450
# Fold 4, Epoch 6/50, Train Loss: 0.052900, Val MAE: 0.006019, Val RMSE: 0.058856, Val R2: 0.673364
# Fold 4, Epoch 7/50, Train Loss: 0.036260, Val MAE: 0.005884, Val RMSE: 0.058110, Val R2: 0.681589
# Fold 4, Epoch 8/50, Train Loss: 0.030047, Val MAE: 0.005480, Val RMSE: 0.057377, Val R2: 0.689570
# Fold 4, Epoch 9/50, Train Loss: 0.030243, Val MAE: 0.004742, Val RMSE: 0.053267, Val R2: 0.732453
# Fold 4, Epoch 10/50, Train Loss: 0.026054, Val MAE: 0.005263, Val RMSE: 0.061368, Val R2: 0.644881
# Fold 4, Epoch 11/50, Train Loss: 0.038835, Val MAE: 0.005073, Val RMSE: 0.054517, Val R2: 0.719753
# Fold 4, Epoch 12/50, Train Loss: 0.024481, Val MAE: 0.004940, Val RMSE: 0.052606, Val R2: 0.739050
# Fold 4, Epoch 13/50, Train Loss: 0.019905, Val MAE: 0.005136, Val RMSE: 0.053863, Val R2: 0.726435
# Fold 4, Epoch 14/50, Train Loss: 0.022831, Val MAE: 0.005796, Val RMSE: 0.059074, Val R2: 0.670944
# Fold 4, Epoch 15/50, Train Loss: 0.015041, Val MAE: 0.004549, Val RMSE: 0.051797, Val R2: 0.747013
# Fold 4, Epoch 16/50, Train Loss: 0.014027, Val MAE: 0.004631, Val RMSE: 0.053557, Val R2: 0.729535
# Fold 4, Epoch 17/50, Train Loss: 0.021881, Val MAE: 0.008116, Val RMSE: 0.063857, Val R2: 0.615495
# Fold 4, Epoch 18/50, Train Loss: 0.026251, Val MAE: 0.004844, Val RMSE: 0.054270, Val R2: 0.722287
# Fold 4, Epoch 19/50, Train Loss: 0.013970, Val MAE: 0.004557, Val RMSE: 0.051223, Val R2: 0.752594
# Fold 4, Epoch 20/50, Train Loss: 0.008067, Val MAE: 0.004424, Val RMSE: 0.050839, Val R2: 0.756288
# Fold 4, Epoch 21/50, Train Loss: 0.011640, Val MAE: 0.005908, Val RMSE: 0.051420, Val R2: 0.750683
# Fold 4, Epoch 22/50, Train Loss: 0.006076, Val MAE: 0.004424, Val RMSE: 0.049510, Val R2: 0.768866
# Fold 4, Epoch 23/50, Train Loss: 0.008848, Val MAE: 0.004698, Val RMSE: 0.053590, Val R2: 0.729195
# Fold 4, Epoch 24/50, Train Loss: 0.014236, Val MAE: 0.004788, Val RMSE: 0.050762, Val R2: 0.757021
# Fold 4, Epoch 25/50, Train Loss: 0.013795, Val MAE: 0.004050, Val RMSE: 0.047292, Val R2: 0.789105
# Fold 4, Epoch 26/50, Train Loss: 0.007977, Val MAE: 0.004289, Val RMSE: 0.048112, Val R2: 0.781731
# Fold 4, Epoch 27/50, Train Loss: 0.009851, Val MAE: 0.004126, Val RMSE: 0.047486, Val R2: 0.787375
# Fold 4, Epoch 28/50, Train Loss: 0.008787, Val MAE: 0.004300, Val RMSE: 0.048977, Val R2: 0.773810
# Fold 4, Epoch 29/50, Train Loss: 0.007341, Val MAE: 0.004178, Val RMSE: 0.048673, Val R2: 0.776608
# Fold 4, Epoch 30/50, Train Loss: 0.010036, Val MAE: 0.004435, Val RMSE: 0.051068, Val R2: 0.754085
# Fold 4, Epoch 31/50, Train Loss: 0.012044, Val MAE: 0.004334, Val RMSE: 0.049790, Val R2: 0.766241
# Fold 4, Epoch 32/50, Train Loss: 0.008101, Val MAE: 0.004205, Val RMSE: 0.048694, Val R2: 0.776417
# Fold 4, Epoch 33/50, Train Loss: 0.007282, Val MAE: 0.004434, Val RMSE: 0.052083, Val R2: 0.744217
# Fold 4, Epoch 34/50, Train Loss: 0.020839, Val MAE: 0.004099, Val RMSE: 0.047315, Val R2: 0.788900
# Fold 4, Epoch 35/50, Train Loss: 0.031956, Val MAE: 0.004653, Val RMSE: 0.050367, Val R2: 0.760788
# Fold 4, Epoch 36/50, Train Loss: 0.014670, Val MAE: 0.005318, Val RMSE: 0.052277, Val R2: 0.742303
# Fold 4, Epoch 37/50, Train Loss: 0.005635, Val MAE: 0.004984, Val RMSE: 0.050381, Val R2: 0.760657
# Fold 4, Epoch 38/50, Train Loss: 0.006663, Val MAE: 0.004279, Val RMSE: 0.046762, Val R2: 0.793806
# Fold 4, Epoch 39/50, Train Loss: 0.016905, Val MAE: 0.005002, Val RMSE: 0.052024, Val R2: 0.744795
# Fold 4, Epoch 40/50, Train Loss: 0.008449, Val MAE: 0.005439, Val RMSE: 0.052918, Val R2: 0.735945
# Fold 4, Epoch 41/50, Train Loss: 0.005717, Val MAE: 0.004974, Val RMSE: 0.050649, Val R2: 0.758106
# Fold 4, Epoch 42/50, Train Loss: 0.006182, Val MAE: 0.004550, Val RMSE: 0.048006, Val R2: 0.782696
# Fold 4, Epoch 43/50, Train Loss: 0.005092, Val MAE: 0.004484, Val RMSE: 0.048602, Val R2: 0.777265
# Fold 4, Epoch 44/50, Train Loss: 0.005448, Val MAE: 0.005110, Val RMSE: 0.049806, Val R2: 0.766091
# Fold 4, Epoch 45/50, Train Loss: 0.004514, Val MAE: 0.005382, Val RMSE: 0.049961, Val R2: 0.764630
# Fold 4, Epoch 46/50, Train Loss: 0.004665, Val MAE: 0.003991, Val RMSE: 0.046519, Val R2: 0.795943
# Fold 4, Epoch 47/50, Train Loss: 0.004641, Val MAE: 0.004082, Val RMSE: 0.045851, Val R2: 0.801768
# Fold 4, Epoch 48/50, Train Loss: 0.004629, Val MAE: 0.004543, Val RMSE: 0.048439, Val R2: 0.778757
# Fold 4, Epoch 49/50, Train Loss: 0.006585, Val MAE: 0.005243, Val RMSE: 0.053804, Val R2: 0.727032
# Fold 4, Epoch 50/50, Train Loss: 0.005535, Val MAE: 0.004194, Val RMSE: 0.046775, Val R2: 0.793692
# ==================================================
# Spatial Fold 5/5
# ==================================================
# mode: train
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 108
# mode: val
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 29
# Fold 5, Epoch 1/50, Train Loss: 0.194982, Val MAE: 0.058317, Val RMSE: 0.322197, Val R2: 0.639118
# Fold 5, Epoch 2/50, Train Loss: 0.106796, Val MAE: 0.057181, Val RMSE: 0.283405, Val R2: 0.720785
# Fold 5, Epoch 3/50, Train Loss: 0.097208, Val MAE: 0.050666, Val RMSE: 0.248070, Val R2: 0.786069
# Fold 5, Epoch 4/50, Train Loss: 0.072544, Val MAE: 0.047406, Val RMSE: 0.231275, Val R2: 0.814056
# Fold 5, Epoch 5/50, Train Loss: 0.060936, Val MAE: 0.041834, Val RMSE: 0.205151, Val R2: 0.853691
# Fold 5, Epoch 6/50, Train Loss: 0.049594, Val MAE: 0.056080, Val RMSE: 0.295718, Val R2: 0.695997
# Fold 5, Epoch 7/50, Train Loss: 0.040033, Val MAE: 0.043917, Val RMSE: 0.216246, Val R2: 0.837437
# Fold 5, Epoch 8/50, Train Loss: 0.034650, Val MAE: 0.041388, Val RMSE: 0.223059, Val R2: 0.827034
# Fold 5, Epoch 9/50, Train Loss: 0.027616, Val MAE: 0.039371, Val RMSE: 0.195977, Val R2: 0.866484
# Fold 5, Epoch 10/50, Train Loss: 0.021877, Val MAE: 0.037429, Val RMSE: 0.192706, Val R2: 0.870904
# Fold 5, Epoch 11/50, Train Loss: 0.024543, Val MAE: 0.047319, Val RMSE: 0.260357, Val R2: 0.764353
# Fold 5, Epoch 12/50, Train Loss: 0.017471, Val MAE: 0.042352, Val RMSE: 0.252565, Val R2: 0.778248
# Fold 5, Epoch 13/50, Train Loss: 0.025099, Val MAE: 0.044071, Val RMSE: 0.250735, Val R2: 0.781449
# Fold 5, Epoch 14/50, Train Loss: 0.023148, Val MAE: 0.052825, Val RMSE: 0.258530, Val R2: 0.767649
# Fold 5, Epoch 15/50, Train Loss: 0.020939, Val MAE: 0.042178, Val RMSE: 0.213678, Val R2: 0.841276
# Fold 5, Epoch 16/50, Train Loss: 0.016778, Val MAE: 0.037104, Val RMSE: 0.207523, Val R2: 0.850288
# Fold 5, Epoch 17/50, Train Loss: 0.009639, Val MAE: 0.036233, Val RMSE: 0.205522, Val R2: 0.853162
# Fold 5, Epoch 18/50, Train Loss: 0.014037, Val MAE: 0.037693, Val RMSE: 0.260023, Val R2: 0.764958
# Fold 5, Epoch 19/50, Train Loss: 0.014793, Val MAE: 0.035390, Val RMSE: 0.198656, Val R2: 0.862809
# Fold 5, Epoch 20/50, Train Loss: 0.009198, Val MAE: 0.034695, Val RMSE: 0.211095, Val R2: 0.845090
# Fold 5, Epoch 21/50, Train Loss: 0.007090, Val MAE: 0.036814, Val RMSE: 0.220293, Val R2: 0.831296
# Fold 5, Epoch 22/50, Train Loss: 0.007069, Val MAE: 0.035632, Val RMSE: 0.192368, Val R2: 0.871356
# Fold 5, Epoch 23/50, Train Loss: 0.016307, Val MAE: 0.035212, Val RMSE: 0.198798, Val R2: 0.862613
# Fold 5, Epoch 24/50, Train Loss: 0.012495, Val MAE: 0.034372, Val RMSE: 0.220230, Val R2: 0.831393
# Fold 5, Epoch 25/50, Train Loss: 0.009793, Val MAE: 0.037212, Val RMSE: 0.186531, Val R2: 0.879044
# Fold 5, Epoch 26/50, Train Loss: 0.007818, Val MAE: 0.037471, Val RMSE: 0.251783, Val R2: 0.779619
# Fold 5, Epoch 27/50, Train Loss: 0.008245, Val MAE: 0.030777, Val RMSE: 0.161246, Val R2: 0.909614
# Fold 5, Epoch 28/50, Train Loss: 0.013290, Val MAE: 0.036779, Val RMSE: 0.235231, Val R2: 0.807640
# Fold 5, Epoch 29/50, Train Loss: 0.006793, Val MAE: 0.033394, Val RMSE: 0.201205, Val R2: 0.859265
# Fold 5, Epoch 30/50, Train Loss: 0.006737, Val MAE: 0.043586, Val RMSE: 0.245658, Val R2: 0.790210
# Fold 5, Epoch 31/50, Train Loss: 0.004980, Val MAE: 0.035292, Val RMSE: 0.190964, Val R2: 0.873227
# Fold 5, Epoch 32/50, Train Loss: 0.012092, Val MAE: 0.040427, Val RMSE: 0.212765, Val R2: 0.842630
# Fold 5, Epoch 33/50, Train Loss: 0.011875, Val MAE: 0.035892, Val RMSE: 0.189465, Val R2: 0.875209
# Fold 5, Epoch 34/50, Train Loss: 0.013117, Val MAE: 0.033617, Val RMSE: 0.182927, Val R2: 0.883673
# Fold 5, Epoch 35/50, Train Loss: 0.006149, Val MAE: 0.035174, Val RMSE: 0.267156, Val R2: 0.751884
# Fold 5, Epoch 36/50, Train Loss: 0.007047, Val MAE: 0.035883, Val RMSE: 0.189028, Val R2: 0.875785
# Fold 5, Epoch 37/50, Train Loss: 0.004410, Val MAE: 0.034581, Val RMSE: 0.231327, Val R2: 0.813973
# Fold 5, Epoch 38/50, Train Loss: 0.007248, Val MAE: 0.031550, Val RMSE: 0.196885, Val R2: 0.865244
# Fold 5, Epoch 39/50, Train Loss: 0.006947, Val MAE: 0.030816, Val RMSE: 0.171521, Val R2: 0.897727
# Fold 5, Epoch 40/50, Train Loss: 0.003870, Val MAE: 0.031745, Val RMSE: 0.187531, Val R2: 0.877744
# Fold 5, Epoch 41/50, Train Loss: 0.003012, Val MAE: 0.029559, Val RMSE: 0.167052, Val R2: 0.902988
# Fold 5, Epoch 42/50, Train Loss: 0.002751, Val MAE: 0.030659, Val RMSE: 0.170628, Val R2: 0.898790
# Fold 5, Epoch 43/50, Train Loss: 0.002504, Val MAE: 0.033628, Val RMSE: 0.188186, Val R2: 0.876888
# Fold 5, Epoch 44/50, Train Loss: 0.001706, Val MAE: 0.032079, Val RMSE: 0.195891, Val R2: 0.866601
# Fold 5, Epoch 45/50, Train Loss: 0.004902, Val MAE: 0.036182, Val RMSE: 0.199097, Val R2: 0.862199
# Fold 5, Epoch 46/50, Train Loss: 0.005840, Val MAE: 0.032097, Val RMSE: 0.199209, Val R2: 0.862044
# Fold 5, Epoch 47/50, Train Loss: 0.004424, Val MAE: 0.030018, Val RMSE: 0.159995, Val R2: 0.911011
# Fold 5, Epoch 48/50, Train Loss: 0.003724, Val MAE: 0.031012, Val RMSE: 0.188872, Val R2: 0.875989
# Fold 5, Epoch 49/50, Train Loss: 0.006366, Val MAE: 0.031708, Val RMSE: 0.181604, Val R2: 0.885350
# Fold 5, Epoch 50/50, Train Loss: 0.003085, Val MAE: 0.030244, Val RMSE: 0.167573, Val R2: 0.902382

# %%
import copy
import numpy as np
import pandas as pd
import torch
from torch.utils.data import DataLoader

EARLY_STOPPING_PATIENCE = 10
MIN_DELTA = 1e-4

fold_results = []
fold_best_models = {}

for val_fold in range(5):
    print("=" * 50)
    print(f"Spatial Fold {val_fold + 1}/5")
    print("=" * 50)

    train_dataset = SupervisedFloodDataset(
        X_full=X_full,
        y_full=y_full,
        patch_size=PATCH_SIZE,
        stride=STRIDE,
        fold_map=fold_map,
        val_fold=val_fold,
        mode="train",
        drop_boundary=False
    )

    val_dataset = SupervisedFloodDataset(
        X_full=X_full,
        y_full=y_full,
        patch_size=PATCH_SIZE,
        stride=STRIDE,
        fold_map=fold_map,
        val_fold=val_fold,
        mode="val",
        drop_boundary=False
    )

    train_loader = DataLoader(
        train_dataset,
        batch_size=BATCH_SIZE,
        shuffle=True
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False
    )

    print(f"Train patches: {len(train_dataset)}")
    print(f"Validation patches: {len(val_dataset)}")

    model = UNet(
        in_channels=X_full.shape[0]
    ).to(device)

    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=LEARNING_RATE
    )

    # Best validation metrics for this fold
    best_val_rmse = np.inf
    best_val_mae = np.nan
    best_val_r2 = np.nan
    best_epoch = -1
    best_model_state = None

    # Early-stopping counter
    epochs_without_improvement = 0

    for epoch in range(EPOCHS):
        # =========================
        # Training
        # =========================
        model.train()
        train_losses = []

        for X_batch, y_batch in train_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            optimizer.zero_grad()

            pred = model(X_batch)

            loss_main = masked_mse_loss(
                pred,
                y_batch
            )

            if loss_main is None:
                continue

            loss_smooth = smoothness_loss(pred)

            loss = (
                loss_main
                + SMOOTHNESS_WEIGHT * loss_smooth
            )

            if not torch.isfinite(loss):
                print("Non-finite training loss detected. Batch skipped.")
                continue

            loss.backward()
            optimizer.step()

            train_losses.append(loss.item())

        train_loss = (
            np.mean(train_losses)
            if len(train_losses) > 0
            else np.nan
        )

        # =========================
        # Validation
        # =========================
        val_mae, val_rmse, val_r2 = validate_model(
            model,
            val_loader,
            device
        )

        print(
            f"Fold {val_fold + 1}, "
            f"Epoch {epoch + 1}/{EPOCHS}, "
            f"Train Loss: {train_loss:.6f}, "
            f"Val MAE: {val_mae:.6f}, "
            f"Val RMSE: {val_rmse:.6f}, "
            f"Val R2: {val_r2:.6f}"
        )

        # =========================
        # Early stopping
        # =========================
        if not np.isfinite(val_rmse):
            epochs_without_improvement += 1

            print(
                "Validation RMSE is not finite. "
                f"Patience: {epochs_without_improvement}/"
                f"{EARLY_STOPPING_PATIENCE}"
            )

        elif val_rmse < best_val_rmse - MIN_DELTA:
            best_val_rmse = val_rmse
            best_val_mae = val_mae
            best_val_r2 = val_r2
            best_epoch = epoch + 1

            # Save a copy of the best model weights
            best_model_state = copy.deepcopy(
                model.state_dict()
            )

            # Reset patience
            epochs_without_improvement = 0

            print(
                f"New best model for fold {val_fold + 1}: "
                f"RMSE = {best_val_rmse:.6f}"
            )

        else:
            epochs_without_improvement += 1

            print(
                f"No improvement. Patience: "
                f"{epochs_without_improvement}/"
                f"{EARLY_STOPPING_PATIENCE}"
            )

        if epochs_without_improvement >= EARLY_STOPPING_PATIENCE:
            print(
                f"Early stopping fold {val_fold + 1} "
                f"at epoch {epoch + 1}."
            )
            break

    # Restore the best model for this fold
    if best_model_state is not None:
        model.load_state_dict(best_model_state)

        # Store on CPU to reduce GPU memory use
        fold_best_models[val_fold + 1] = {
            key: value.detach().cpu().clone()
            for key, value in best_model_state.items()
        }

        print(
            f"Fold {val_fold + 1} finished. "
            f"Best epoch: {best_epoch}, "
            f"Best RMSE: {best_val_rmse:.6f}"
        )

    else:
        print(
            f"Warning: Fold {val_fold + 1} did not produce "
            "a valid validation RMSE."
        )

    fold_results.append({
        "fold": val_fold + 1,
        "best_epoch": best_epoch,
        "MAE": best_val_mae,
        "RMSE": best_val_rmse
        if np.isfinite(best_val_rmse)
        else np.nan,
        "R2": best_val_r2,
        "epochs_run": epoch + 1
    })

    # Release GPU memory before the next fold
    del model
    del optimizer
    torch.cuda.empty_cache()
# Out:
# ==================================================
# Spatial Fold 1/5
# ==================================================
# mode: train
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 113
# mode: val
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 24
# Train patches: 113
# Validation patches: 24
# Fold 1, Epoch 1/50, Train Loss: 0.170079, Val MAE: 0.102530, Val RMSE: 0.403257, Val R2: 0.633676
# New best model for fold 1: RMSE = 0.403257
# Fold 1, Epoch 2/50, Train Loss: 0.083936, Val MAE: 0.079680, Val RMSE: 0.352996, Val R2: 0.719302
# New best model for fold 1: RMSE = 0.352996
# Fold 1, Epoch 3/50, Train Loss: 0.072579, Val MAE: 0.116069, Val RMSE: 0.483140, Val R2: 0.474168
# No improvement. Patience: 1/10
# Fold 1, Epoch 4/50, Train Loss: 0.077964, Val MAE: 0.085833, Val RMSE: 0.386137, Val R2: 0.664121
# No improvement. Patience: 2/10
# Fold 1, Epoch 5/50, Train Loss: 0.056182, Val MAE: 0.069932, Val RMSE: 0.338821, Val R2: 0.741392
# New best model for fold 1: RMSE = 0.338821
# Fold 1, Epoch 6/50, Train Loss: 0.071568, Val MAE: 0.059549, Val RMSE: 0.290260, Val R2: 0.810209
# New best model for fold 1: RMSE = 0.290260
# Fold 1, Epoch 7/50, Train Loss: 0.033721, Val MAE: 0.074647, Val RMSE: 0.357763, Val R2: 0.711669
# No improvement. Patience: 1/10
# Fold 1, Epoch 8/50, Train Loss: 0.034821, Val MAE: 0.061722, Val RMSE: 0.303010, Val R2: 0.793169
# No improvement. Patience: 2/10
# Fold 1, Epoch 9/50, Train Loss: 0.032884, Val MAE: 0.082717, Val RMSE: 0.370616, Val R2: 0.690579
# No improvement. Patience: 3/10
# Fold 1, Epoch 10/50, Train Loss: 0.028835, Val MAE: 0.068648, Val RMSE: 0.381490, Val R2: 0.672156
# No improvement. Patience: 4/10
# Fold 1, Epoch 11/50, Train Loss: 0.022951, Val MAE: 0.065353, Val RMSE: 0.322564, Val R2: 0.765613
# No improvement. Patience: 5/10
# Fold 1, Epoch 12/50, Train Loss: 0.024068, Val MAE: 0.067259, Val RMSE: 0.422130, Val R2: 0.598585
# No improvement. Patience: 6/10
# Fold 1, Epoch 13/50, Train Loss: 0.019275, Val MAE: 0.071627, Val RMSE: 0.394358, Val R2: 0.649667
# No improvement. Patience: 7/10
# Fold 1, Epoch 14/50, Train Loss: 0.015417, Val MAE: 0.068570, Val RMSE: 0.348341, Val R2: 0.726656
# No improvement. Patience: 8/10
# Fold 1, Epoch 15/50, Train Loss: 0.013021, Val MAE: 0.060947, Val RMSE: 0.335188, Val R2: 0.746909
# No improvement. Patience: 9/10
# Fold 1, Epoch 16/50, Train Loss: 0.014455, Val MAE: 0.067190, Val RMSE: 0.337384, Val R2: 0.743581
# No improvement. Patience: 10/10
# Early stopping fold 1 at epoch 16.
# Fold 1 finished. Best epoch: 6, Best RMSE: 0.290260
# ==================================================
# Spatial Fold 2/5
# ==================================================
# mode: train
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 120
# mode: val
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 17
# Train patches: 120
# Validation patches: 17
# Fold 2, Epoch 1/50, Train Loss: 0.135050, Val MAE: 0.194760, Val RMSE: 0.613381, Val R2: 0.538894
# New best model for fold 2: RMSE = 0.613381
# Fold 2, Epoch 2/50, Train Loss: 0.071900, Val MAE: 0.177673, Val RMSE: 0.570632, Val R2: 0.600926
# New best model for fold 2: RMSE = 0.570632
# Fold 2, Epoch 3/50, Train Loss: 0.063543, Val MAE: 0.195775, Val RMSE: 0.567602, Val R2: 0.605153
# New best model for fold 2: RMSE = 0.567602
# Fold 2, Epoch 4/50, Train Loss: 0.055794, Val MAE: 0.160030, Val RMSE: 0.519906, Val R2: 0.668724
# New best model for fold 2: RMSE = 0.519906
# Fold 2, Epoch 5/50, Train Loss: 0.030629, Val MAE: 0.159083, Val RMSE: 0.517241, Val R2: 0.672112
# New best model for fold 2: RMSE = 0.517241
# Fold 2, Epoch 6/50, Train Loss: 0.037169, Val MAE: 0.233083, Val RMSE: 0.616799, Val R2: 0.533741
# No improvement. Patience: 1/10
# Fold 2, Epoch 7/50, Train Loss: 0.038636, Val MAE: 0.169938, Val RMSE: 0.498259, Val R2: 0.695736
# New best model for fold 2: RMSE = 0.498259
# Fold 2, Epoch 8/50, Train Loss: 0.030444, Val MAE: 0.166511, Val RMSE: 0.523274, Val R2: 0.664417
# No improvement. Patience: 1/10
# Fold 2, Epoch 9/50, Train Loss: 0.016360, Val MAE: 0.162810, Val RMSE: 0.490709, Val R2: 0.704887
# New best model for fold 2: RMSE = 0.490709
# Fold 2, Epoch 10/50, Train Loss: 0.019294, Val MAE: 0.158931, Val RMSE: 0.482928, Val R2: 0.714172
# New best model for fold 2: RMSE = 0.482928
# Fold 2, Epoch 11/50, Train Loss: 0.014187, Val MAE: 0.138324, Val RMSE: 0.428092, Val R2: 0.775398
# New best model for fold 2: RMSE = 0.428092
# Fold 2, Epoch 12/50, Train Loss: 0.014236, Val MAE: 0.132998, Val RMSE: 0.430686, Val R2: 0.772667
# No improvement. Patience: 1/10
# Fold 2, Epoch 13/50, Train Loss: 0.011255, Val MAE: 0.166903, Val RMSE: 0.521450, Val R2: 0.666753
# No improvement. Patience: 2/10
# Fold 2, Epoch 14/50, Train Loss: 0.014581, Val MAE: 0.165850, Val RMSE: 0.574890, Val R2: 0.594948
# No improvement. Patience: 3/10
# Fold 2, Epoch 15/50, Train Loss: 0.011833, Val MAE: 0.161955, Val RMSE: 0.479407, Val R2: 0.718325
# No improvement. Patience: 4/10
# Fold 2, Epoch 16/50, Train Loss: 0.009658, Val MAE: 0.133839, Val RMSE: 0.395469, Val R2: 0.808325
# New best model for fold 2: RMSE = 0.395469
# Fold 2, Epoch 17/50, Train Loss: 0.011604, Val MAE: 0.171046, Val RMSE: 0.478349, Val R2: 0.719567
# No improvement. Patience: 1/10
# Fold 2, Epoch 18/50, Train Loss: 0.011127, Val MAE: 0.126273, Val RMSE: 0.407628, Val R2: 0.796358
# No improvement. Patience: 2/10
# Fold 2, Epoch 19/50, Train Loss: 0.012322, Val MAE: 0.175078, Val RMSE: 0.586006, Val R2: 0.579133
# No improvement. Patience: 3/10
# Fold 2, Epoch 20/50, Train Loss: 0.008739, Val MAE: 0.138584, Val RMSE: 0.426734, Val R2: 0.776820
# No improvement. Patience: 4/10
# Fold 2, Epoch 21/50, Train Loss: 0.008175, Val MAE: 0.132898, Val RMSE: 0.411091, Val R2: 0.792883
# No improvement. Patience: 5/10
# Fold 2, Epoch 22/50, Train Loss: 0.007236, Val MAE: 0.132627, Val RMSE: 0.441332, Val R2: 0.761289
# No improvement. Patience: 6/10
# Fold 2, Epoch 23/50, Train Loss: 0.007600, Val MAE: 0.136682, Val RMSE: 0.433381, Val R2: 0.769813
# No improvement. Patience: 7/10
# Fold 2, Epoch 24/50, Train Loss: 0.008956, Val MAE: 0.128480, Val RMSE: 0.420072, Val R2: 0.783734
# No improvement. Patience: 8/10
# Fold 2, Epoch 25/50, Train Loss: 0.007354, Val MAE: 0.143950, Val RMSE: 0.435397, Val R2: 0.767666
# No improvement. Patience: 9/10
# Fold 2, Epoch 26/50, Train Loss: 0.008983, Val MAE: 0.132573, Val RMSE: 0.401329, Val R2: 0.802603
# No improvement. Patience: 10/10
# Early stopping fold 2 at epoch 26.
# Fold 2 finished. Best epoch: 16, Best RMSE: 0.395469
# ==================================================
# Spatial Fold 3/5
# ==================================================
# mode: train
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 102
# mode: val
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 35
# Train patches: 102
# Validation patches: 35
# Fold 3, Epoch 1/50, Train Loss: 0.197235, Val MAE: 0.028446, Val RMSE: 0.295434, Val R2: 0.505184
# New best model for fold 3: RMSE = 0.295434
# Fold 3, Epoch 2/50, Train Loss: 0.117575, Val MAE: 0.025590, Val RMSE: 0.226558, Val R2: 0.709009
# New best model for fold 3: RMSE = 0.226558
# Fold 3, Epoch 3/50, Train Loss: 0.121199, Val MAE: 0.022507, Val RMSE: 0.205942, Val R2: 0.759558
# New best model for fold 3: RMSE = 0.205942
# Fold 3, Epoch 4/50, Train Loss: 0.078211, Val MAE: 0.024909, Val RMSE: 0.229682, Val R2: 0.700927
# No improvement. Patience: 1/10
# Fold 3, Epoch 5/50, Train Loss: 0.063891, Val MAE: 0.023154, Val RMSE: 0.207120, Val R2: 0.756800
# No improvement. Patience: 2/10
# Fold 3, Epoch 6/50, Train Loss: 0.054094, Val MAE: 0.029044, Val RMSE: 0.262635, Val R2: 0.608954
# No improvement. Patience: 3/10
# Fold 3, Epoch 7/50, Train Loss: 0.041615, Val MAE: 0.024655, Val RMSE: 0.236427, Val R2: 0.683104
# No improvement. Patience: 4/10
# Fold 3, Epoch 8/50, Train Loss: 0.031457, Val MAE: 0.022356, Val RMSE: 0.214115, Val R2: 0.740094
# No improvement. Patience: 5/10
# Fold 3, Epoch 9/50, Train Loss: 0.036179, Val MAE: 0.025042, Val RMSE: 0.183889, Val R2: 0.808296
# New best model for fold 3: RMSE = 0.183889
# Fold 3, Epoch 10/50, Train Loss: 0.026901, Val MAE: 0.023856, Val RMSE: 0.190725, Val R2: 0.793777
# No improvement. Patience: 1/10
# Fold 3, Epoch 11/50, Train Loss: 0.030659, Val MAE: 0.020116, Val RMSE: 0.190309, Val R2: 0.794677
# No improvement. Patience: 2/10
# Fold 3, Epoch 12/50, Train Loss: 0.022242, Val MAE: 0.017498, Val RMSE: 0.166754, Val R2: 0.842357
# New best model for fold 3: RMSE = 0.166754
# Fold 3, Epoch 13/50, Train Loss: 0.025997, Val MAE: 0.018411, Val RMSE: 0.169593, Val R2: 0.836944
# No improvement. Patience: 1/10
# Fold 3, Epoch 14/50, Train Loss: 0.021590, Val MAE: 0.020015, Val RMSE: 0.192900, Val R2: 0.789046
# No improvement. Patience: 2/10
# Fold 3, Epoch 15/50, Train Loss: 0.018870, Val MAE: 0.017851, Val RMSE: 0.163834, Val R2: 0.847830
# New best model for fold 3: RMSE = 0.163834
# Fold 3, Epoch 16/50, Train Loss: 0.027436, Val MAE: 0.017103, Val RMSE: 0.185085, Val R2: 0.805793
# No improvement. Patience: 1/10
# Fold 3, Epoch 17/50, Train Loss: 0.014726, Val MAE: 0.016736, Val RMSE: 0.157405, Val R2: 0.859538
# New best model for fold 3: RMSE = 0.157405
# Fold 3, Epoch 18/50, Train Loss: 0.010175, Val MAE: 0.018952, Val RMSE: 0.185378, Val R2: 0.805179
# No improvement. Patience: 1/10
# Fold 3, Epoch 19/50, Train Loss: 0.012873, Val MAE: 0.017052, Val RMSE: 0.154572, Val R2: 0.864548
# New best model for fold 3: RMSE = 0.154572
# Fold 3, Epoch 20/50, Train Loss: 0.013014, Val MAE: 0.018572, Val RMSE: 0.219962, Val R2: 0.725705
# No improvement. Patience: 1/10
# Fold 3, Epoch 21/50, Train Loss: 0.010113, Val MAE: 0.016600, Val RMSE: 0.162546, Val R2: 0.850213
# No improvement. Patience: 2/10
# Fold 3, Epoch 22/50, Train Loss: 0.013201, Val MAE: 0.018744, Val RMSE: 0.196862, Val R2: 0.780292
# No improvement. Patience: 3/10
# Fold 3, Epoch 23/50, Train Loss: 0.013779, Val MAE: 0.017577, Val RMSE: 0.156634, Val R2: 0.860912
# No improvement. Patience: 4/10
# Fold 3, Epoch 24/50, Train Loss: 0.014823, Val MAE: 0.016780, Val RMSE: 0.174521, Val R2: 0.827331
# No improvement. Patience: 5/10
# Fold 3, Epoch 25/50, Train Loss: 0.010598, Val MAE: 0.014826, Val RMSE: 0.149080, Val R2: 0.874002
# New best model for fold 3: RMSE = 0.149080
# Fold 3, Epoch 26/50, Train Loss: 0.011683, Val MAE: 0.018035, Val RMSE: 0.189939, Val R2: 0.795473
# No improvement. Patience: 1/10
# Fold 3, Epoch 27/50, Train Loss: 0.014941, Val MAE: 0.016097, Val RMSE: 0.153790, Val R2: 0.865915
# No improvement. Patience: 2/10
# Fold 3, Epoch 28/50, Train Loss: 0.010698, Val MAE: 0.015186, Val RMSE: 0.145412, Val R2: 0.880127
# New best model for fold 3: RMSE = 0.145412
# Fold 3, Epoch 29/50, Train Loss: 0.006285, Val MAE: 0.014436, Val RMSE: 0.140501, Val R2: 0.888086
# New best model for fold 3: RMSE = 0.140501
# Fold 3, Epoch 30/50, Train Loss: 0.008725, Val MAE: 0.015367, Val RMSE: 0.152162, Val R2: 0.868740
# No improvement. Patience: 1/10
# Fold 3, Epoch 31/50, Train Loss: 0.008605, Val MAE: 0.015375, Val RMSE: 0.147840, Val R2: 0.876090
# No improvement. Patience: 2/10
# Fold 3, Epoch 32/50, Train Loss: 0.007827, Val MAE: 0.015186, Val RMSE: 0.170125, Val R2: 0.835920
# No improvement. Patience: 3/10
# Fold 3, Epoch 33/50, Train Loss: 0.007580, Val MAE: 0.016039, Val RMSE: 0.154235, Val R2: 0.865140
# No improvement. Patience: 4/10
# Fold 3, Epoch 34/50, Train Loss: 0.008557, Val MAE: 0.015294, Val RMSE: 0.175032, Val R2: 0.826318
# No improvement. Patience: 5/10
# Fold 3, Epoch 35/50, Train Loss: 0.006069, Val MAE: 0.017036, Val RMSE: 0.161313, Val R2: 0.852476
# No improvement. Patience: 6/10
# Fold 3, Epoch 36/50, Train Loss: 0.005396, Val MAE: 0.016151, Val RMSE: 0.166326, Val R2: 0.843166
# No improvement. Patience: 7/10
# Fold 3, Epoch 37/50, Train Loss: 0.005924, Val MAE: 0.014777, Val RMSE: 0.140911, Val R2: 0.887433
# No improvement. Patience: 8/10
# Fold 3, Epoch 38/50, Train Loss: 0.005907, Val MAE: 0.013017, Val RMSE: 0.125838, Val R2: 0.910227
# New best model for fold 3: RMSE = 0.125838
# Fold 3, Epoch 39/50, Train Loss: 0.011122, Val MAE: 0.014720, Val RMSE: 0.138204, Val R2: 0.891716
# No improvement. Patience: 1/10
# Fold 3, Epoch 40/50, Train Loss: 0.006898, Val MAE: 0.015060, Val RMSE: 0.140755, Val R2: 0.887682
# No improvement. Patience: 2/10
# Fold 3, Epoch 41/50, Train Loss: 0.004660, Val MAE: 0.017269, Val RMSE: 0.152895, Val R2: 0.867472
# No improvement. Patience: 3/10
# Fold 3, Epoch 42/50, Train Loss: 0.005805, Val MAE: 0.014563, Val RMSE: 0.142528, Val R2: 0.884834
# No improvement. Patience: 4/10
# Fold 3, Epoch 43/50, Train Loss: 0.010966, Val MAE: 0.017451, Val RMSE: 0.169617, Val R2: 0.836897
# No improvement. Patience: 5/10
# Fold 3, Epoch 44/50, Train Loss: 0.008519, Val MAE: 0.017961, Val RMSE: 0.204988, Val R2: 0.761780
# No improvement. Patience: 6/10
# Fold 3, Epoch 45/50, Train Loss: 0.022169, Val MAE: 0.019313, Val RMSE: 0.203013, Val R2: 0.766349
# No improvement. Patience: 7/10
# Fold 3, Epoch 46/50, Train Loss: 0.007837, Val MAE: 0.023215, Val RMSE: 0.236506, Val R2: 0.682892
# No improvement. Patience: 8/10
# Fold 3, Epoch 47/50, Train Loss: 0.008805, Val MAE: 0.017836, Val RMSE: 0.152526, Val R2: 0.868110
# No improvement. Patience: 9/10
# Fold 3, Epoch 48/50, Train Loss: 0.005036, Val MAE: 0.014637, Val RMSE: 0.136874, Val R2: 0.893791
# No improvement. Patience: 10/10
# Early stopping fold 3 at epoch 48.
# Fold 3 finished. Best epoch: 38, Best RMSE: 0.125838
# ==================================================
# Spatial Fold 4/5
# ==================================================
# mode: train
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 116
# mode: val
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 21
# Train patches: 116
# Validation patches: 21
# Fold 4, Epoch 1/50, Train Loss: 0.199533, Val MAE: 0.023848, Val RMSE: 0.114661, Val R2: 0.755134
# New best model for fold 4: RMSE = 0.114661
# Fold 4, Epoch 2/50, Train Loss: 0.118424, Val MAE: 0.018649, Val RMSE: 0.102994, Val R2: 0.802431
# New best model for fold 4: RMSE = 0.102994
# Fold 4, Epoch 3/50, Train Loss: 0.086742, Val MAE: 0.019606, Val RMSE: 0.104737, Val R2: 0.795688
# No improvement. Patience: 1/10
# Fold 4, Epoch 4/50, Train Loss: 0.074540, Val MAE: 0.023387, Val RMSE: 0.117433, Val R2: 0.743154
# No improvement. Patience: 2/10
# Fold 4, Epoch 5/50, Train Loss: 0.088742, Val MAE: 0.015204, Val RMSE: 0.100015, Val R2: 0.813694
# New best model for fold 4: RMSE = 0.100015
# Fold 4, Epoch 6/50, Train Loss: 0.047787, Val MAE: 0.022402, Val RMSE: 0.116107, Val R2: 0.748923
# No improvement. Patience: 1/10
# Fold 4, Epoch 7/50, Train Loss: 0.039613, Val MAE: 0.014951, Val RMSE: 0.093747, Val R2: 0.836314
# New best model for fold 4: RMSE = 0.093747
# Fold 4, Epoch 8/50, Train Loss: 0.036126, Val MAE: 0.020429, Val RMSE: 0.115475, Val R2: 0.751647
# No improvement. Patience: 1/10
# Fold 4, Epoch 9/50, Train Loss: 0.028001, Val MAE: 0.015433, Val RMSE: 0.095434, Val R2: 0.830370
# No improvement. Patience: 2/10
# Fold 4, Epoch 10/50, Train Loss: 0.024320, Val MAE: 0.016532, Val RMSE: 0.103970, Val R2: 0.798669
# No improvement. Patience: 3/10
# Fold 4, Epoch 11/50, Train Loss: 0.021273, Val MAE: 0.015234, Val RMSE: 0.095072, Val R2: 0.831654
# No improvement. Patience: 4/10
# Fold 4, Epoch 12/50, Train Loss: 0.016389, Val MAE: 0.016296, Val RMSE: 0.095404, Val R2: 0.830476
# No improvement. Patience: 5/10
# Fold 4, Epoch 13/50, Train Loss: 0.011730, Val MAE: 0.012677, Val RMSE: 0.086473, Val R2: 0.860733
# New best model for fold 4: RMSE = 0.086473
# Fold 4, Epoch 14/50, Train Loss: 0.011263, Val MAE: 0.015038, Val RMSE: 0.090820, Val R2: 0.846376
# No improvement. Patience: 1/10
# Fold 4, Epoch 15/50, Train Loss: 0.021241, Val MAE: 0.014410, Val RMSE: 0.089878, Val R2: 0.849548
# No improvement. Patience: 2/10
# Fold 4, Epoch 16/50, Train Loss: 0.016543, Val MAE: 0.017014, Val RMSE: 0.101513, Val R2: 0.808073
# No improvement. Patience: 3/10
# Fold 4, Epoch 17/50, Train Loss: 0.015481, Val MAE: 0.012698, Val RMSE: 0.084479, Val R2: 0.867080
# New best model for fold 4: RMSE = 0.084479
# Fold 4, Epoch 18/50, Train Loss: 0.011512, Val MAE: 0.012955, Val RMSE: 0.086849, Val R2: 0.859516
# No improvement. Patience: 1/10
# Fold 4, Epoch 19/50, Train Loss: 0.014521, Val MAE: 0.013528, Val RMSE: 0.089197, Val R2: 0.851820
# No improvement. Patience: 2/10
# Fold 4, Epoch 20/50, Train Loss: 0.015014, Val MAE: 0.014567, Val RMSE: 0.092109, Val R2: 0.841987
# No improvement. Patience: 3/10
# Fold 4, Epoch 21/50, Train Loss: 0.009021, Val MAE: 0.014110, Val RMSE: 0.088874, Val R2: 0.852888
# No improvement. Patience: 4/10
# Fold 4, Epoch 22/50, Train Loss: 0.007546, Val MAE: 0.012246, Val RMSE: 0.084247, Val R2: 0.867811
# New best model for fold 4: RMSE = 0.084247
# Fold 4, Epoch 23/50, Train Loss: 0.010325, Val MAE: 0.016279, Val RMSE: 0.098526, Val R2: 0.819201
# No improvement. Patience: 1/10
# Fold 4, Epoch 24/50, Train Loss: 0.011879, Val MAE: 0.017252, Val RMSE: 0.101757, Val R2: 0.807149
# No improvement. Patience: 2/10
# Fold 4, Epoch 25/50, Train Loss: 0.007973, Val MAE: 0.013892, Val RMSE: 0.086945, Val R2: 0.859207
# No improvement. Patience: 3/10
# Fold 4, Epoch 26/50, Train Loss: 0.006539, Val MAE: 0.012513, Val RMSE: 0.081101, Val R2: 0.877498
# New best model for fold 4: RMSE = 0.081101
# Fold 4, Epoch 27/50, Train Loss: 0.005114, Val MAE: 0.012472, Val RMSE: 0.081734, Val R2: 0.875579
# No improvement. Patience: 1/10
# Fold 4, Epoch 28/50, Train Loss: 0.008863, Val MAE: 0.011722, Val RMSE: 0.081416, Val R2: 0.876543
# No improvement. Patience: 2/10
# Fold 4, Epoch 29/50, Train Loss: 0.008273, Val MAE: 0.012290, Val RMSE: 0.080523, Val R2: 0.879237
# New best model for fold 4: RMSE = 0.080523
# Fold 4, Epoch 30/50, Train Loss: 0.007192, Val MAE: 0.011438, Val RMSE: 0.078140, Val R2: 0.886278
# New best model for fold 4: RMSE = 0.078140
# Fold 4, Epoch 31/50, Train Loss: 0.006012, Val MAE: 0.012410, Val RMSE: 0.083268, Val R2: 0.870862
# No improvement. Patience: 1/10
# Fold 4, Epoch 32/50, Train Loss: 0.006133, Val MAE: 0.011232, Val RMSE: 0.079381, Val R2: 0.882640
# No improvement. Patience: 2/10
# Fold 4, Epoch 33/50, Train Loss: 0.006262, Val MAE: 0.012893, Val RMSE: 0.084280, Val R2: 0.867705
# No improvement. Patience: 3/10
# Fold 4, Epoch 34/50, Train Loss: 0.011062, Val MAE: 0.011934, Val RMSE: 0.080613, Val R2: 0.878968
# No improvement. Patience: 4/10
# Fold 4, Epoch 35/50, Train Loss: 0.015868, Val MAE: 0.013764, Val RMSE: 0.088521, Val R2: 0.854056
# No improvement. Patience: 5/10
# Fold 4, Epoch 36/50, Train Loss: 0.009416, Val MAE: 0.012254, Val RMSE: 0.082902, Val R2: 0.871995
# No improvement. Patience: 6/10
# Fold 4, Epoch 37/50, Train Loss: 0.005803, Val MAE: 0.021856, Val RMSE: 0.123854, Val R2: 0.714300
# No improvement. Patience: 7/10
# Fold 4, Epoch 38/50, Train Loss: 0.004610, Val MAE: 0.010496, Val RMSE: 0.075867, Val R2: 0.892799
# New best model for fold 4: RMSE = 0.075867
# Fold 4, Epoch 39/50, Train Loss: 0.018389, Val MAE: 0.015592, Val RMSE: 0.096892, Val R2: 0.825149
# No improvement. Patience: 1/10
# Fold 4, Epoch 40/50, Train Loss: 0.024266, Val MAE: 0.016741, Val RMSE: 0.099045, Val R2: 0.817292
# No improvement. Patience: 2/10
# Fold 4, Epoch 41/50, Train Loss: 0.012585, Val MAE: 0.014756, Val RMSE: 0.091347, Val R2: 0.844588
# No improvement. Patience: 3/10
# Fold 4, Epoch 42/50, Train Loss: 0.010562, Val MAE: 0.025706, Val RMSE: 0.133683, Val R2: 0.667153
# No improvement. Patience: 4/10
# Fold 4, Epoch 43/50, Train Loss: 0.008035, Val MAE: 0.013294, Val RMSE: 0.086210, Val R2: 0.861578
# No improvement. Patience: 5/10
# Fold 4, Epoch 44/50, Train Loss: 0.004931, Val MAE: 0.012823, Val RMSE: 0.083753, Val R2: 0.869354
# No improvement. Patience: 6/10
# Fold 4, Epoch 45/50, Train Loss: 0.005332, Val MAE: 0.017970, Val RMSE: 0.108437, Val R2: 0.780996
# No improvement. Patience: 7/10
# Fold 4, Epoch 46/50, Train Loss: 0.008932, Val MAE: 0.013022, Val RMSE: 0.083040, Val R2: 0.871570
# No improvement. Patience: 8/10
# Fold 4, Epoch 47/50, Train Loss: 0.007052, Val MAE: 0.014562, Val RMSE: 0.088870, Val R2: 0.852904
# No improvement. Patience: 9/10
# Fold 4, Epoch 48/50, Train Loss: 0.004679, Val MAE: 0.014006, Val RMSE: 0.088879, Val R2: 0.852875
# No improvement. Patience: 10/10
# Early stopping fold 4 at epoch 48.
# Fold 4 finished. Best epoch: 38, Best RMSE: 0.075867
# ==================================================
# Spatial Fold 5/5
# ==================================================
# mode: train
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 97
# mode: val
# total patches: 180
# valid y patches: 137
# boundary removed: 0
# kept samples: 40
# Train patches: 97
# Validation patches: 40
# Fold 5, Epoch 1/50, Train Loss: 0.223274, Val MAE: 0.031367, Val RMSE: 0.245906, Val R2: 0.653576
# New best model for fold 5: RMSE = 0.245906
# Fold 5, Epoch 2/50, Train Loss: 0.153531, Val MAE: 0.031473, Val RMSE: 0.235409, Val R2: 0.682521
# New best model for fold 5: RMSE = 0.235409
# Fold 5, Epoch 3/50, Train Loss: 0.115753, Val MAE: 0.037692, Val RMSE: 0.228778, Val R2: 0.700154
# New best model for fold 5: RMSE = 0.228778
# Fold 5, Epoch 4/50, Train Loss: 0.084673, Val MAE: 0.040906, Val RMSE: 0.337006, Val R2: 0.349355
# No improvement. Patience: 1/10
# Fold 5, Epoch 5/50, Train Loss: 0.070330, Val MAE: 0.032145, Val RMSE: 0.232182, Val R2: 0.691163
# No improvement. Patience: 2/10
# Fold 5, Epoch 6/50, Train Loss: 0.061065, Val MAE: 0.024895, Val RMSE: 0.181075, Val R2: 0.812161
# New best model for fold 5: RMSE = 0.181075
# Fold 5, Epoch 7/50, Train Loss: 0.069520, Val MAE: 0.025903, Val RMSE: 0.163930, Val R2: 0.846047
# New best model for fold 5: RMSE = 0.163930
# Fold 5, Epoch 8/50, Train Loss: 0.054796, Val MAE: 0.025109, Val RMSE: 0.223785, Val R2: 0.713099
# No improvement. Patience: 1/10
# Fold 5, Epoch 9/50, Train Loss: 0.039482, Val MAE: 0.022270, Val RMSE: 0.174496, Val R2: 0.825563
# No improvement. Patience: 2/10
# Fold 5, Epoch 10/50, Train Loss: 0.038593, Val MAE: 0.025710, Val RMSE: 0.183160, Val R2: 0.807810
# No improvement. Patience: 3/10
# Fold 5, Epoch 11/50, Train Loss: 0.030480, Val MAE: 0.022113, Val RMSE: 0.155601, Val R2: 0.861294
# New best model for fold 5: RMSE = 0.155601
# Fold 5, Epoch 12/50, Train Loss: 0.035404, Val MAE: 0.051654, Val RMSE: 0.508173, Val R2: -0.479423
# No improvement. Patience: 1/10
# Fold 5, Epoch 13/50, Train Loss: 0.044539, Val MAE: 0.043116, Val RMSE: 0.274171, Val R2: 0.569360
# No improvement. Patience: 2/10
# Fold 5, Epoch 14/50, Train Loss: 0.020351, Val MAE: 0.026687, Val RMSE: 0.215203, Val R2: 0.734682
# No improvement. Patience: 3/10
# Fold 5, Epoch 15/50, Train Loss: 0.016523, Val MAE: 0.023800, Val RMSE: 0.218184, Val R2: 0.727280
# No improvement. Patience: 4/10
# Fold 5, Epoch 16/50, Train Loss: 0.015171, Val MAE: 0.024046, Val RMSE: 0.174071, Val R2: 0.826411
# No improvement. Patience: 5/10
# Fold 5, Epoch 17/50, Train Loss: 0.014683, Val MAE: 0.021922, Val RMSE: 0.185059, Val R2: 0.803804
# No improvement. Patience: 6/10
# Fold 5, Epoch 18/50, Train Loss: 0.009626, Val MAE: 0.021093, Val RMSE: 0.144492, Val R2: 0.880393
# New best model for fold 5: RMSE = 0.144492
# Fold 5, Epoch 19/50, Train Loss: 0.017736, Val MAE: 0.024664, Val RMSE: 0.174683, Val R2: 0.825187
# No improvement. Patience: 1/10
# Fold 5, Epoch 20/50, Train Loss: 0.020670, Val MAE: 0.021799, Val RMSE: 0.183588, Val R2: 0.806911
# No improvement. Patience: 2/10
# Fold 5, Epoch 21/50, Train Loss: 0.034030, Val MAE: 0.019897, Val RMSE: 0.141788, Val R2: 0.884828
# New best model for fold 5: RMSE = 0.141788
# Fold 5, Epoch 22/50, Train Loss: 0.034408, Val MAE: 0.018847, Val RMSE: 0.134544, Val R2: 0.896295
# New best model for fold 5: RMSE = 0.134544
# Fold 5, Epoch 23/50, Train Loss: 0.016340, Val MAE: 0.022482, Val RMSE: 0.159231, Val R2: 0.854748
# No improvement. Patience: 1/10
# Fold 5, Epoch 24/50, Train Loss: 0.011767, Val MAE: 0.020693, Val RMSE: 0.141458, Val R2: 0.885363
# No improvement. Patience: 2/10
# Fold 5, Epoch 25/50, Train Loss: 0.013288, Val MAE: 0.019108, Val RMSE: 0.133310, Val R2: 0.898189
# New best model for fold 5: RMSE = 0.133310
# Fold 5, Epoch 26/50, Train Loss: 0.010758, Val MAE: 0.028526, Val RMSE: 0.227834, Val R2: 0.702623
# No improvement. Patience: 1/10
# Fold 5, Epoch 27/50, Train Loss: 0.011079, Val MAE: 0.020246, Val RMSE: 0.152298, Val R2: 0.867121
# No improvement. Patience: 2/10
# Fold 5, Epoch 28/50, Train Loss: 0.009045, Val MAE: 0.019722, Val RMSE: 0.140296, Val R2: 0.887238
# No improvement. Patience: 3/10
# Fold 5, Epoch 29/50, Train Loss: 0.008838, Val MAE: 0.022449, Val RMSE: 0.196323, Val R2: 0.779194
# No improvement. Patience: 4/10
# Fold 5, Epoch 30/50, Train Loss: 0.007375, Val MAE: 0.018691, Val RMSE: 0.129036, Val R2: 0.904613
# New best model for fold 5: RMSE = 0.129036
# Fold 5, Epoch 31/50, Train Loss: 0.008437, Val MAE: 0.021560, Val RMSE: 0.143206, Val R2: 0.882512
# No improvement. Patience: 1/10
# Fold 5, Epoch 32/50, Train Loss: 0.025807, Val MAE: 0.020578, Val RMSE: 0.150412, Val R2: 0.870391
# No improvement. Patience: 2/10
# Fold 5, Epoch 33/50, Train Loss: 0.024902, Val MAE: 0.032219, Val RMSE: 0.215074, Val R2: 0.735000
# No improvement. Patience: 3/10
# Fold 5, Epoch 34/50, Train Loss: 0.012623, Val MAE: 0.025367, Val RMSE: 0.173743, Val R2: 0.827064
# No improvement. Patience: 4/10
# Fold 5, Epoch 35/50, Train Loss: 0.022575, Val MAE: 0.025765, Val RMSE: 0.188576, Val R2: 0.796275
# No improvement. Patience: 5/10
# Fold 5, Epoch 36/50, Train Loss: 0.015060, Val MAE: 0.019693, Val RMSE: 0.157822, Val R2: 0.857307
# No improvement. Patience: 6/10
# Fold 5, Epoch 37/50, Train Loss: 0.027427, Val MAE: 0.019267, Val RMSE: 0.139783, Val R2: 0.888061
# No improvement. Patience: 7/10
# Fold 5, Epoch 38/50, Train Loss: 0.024355, Val MAE: 0.023400, Val RMSE: 0.152146, Val R2: 0.867386
# No improvement. Patience: 8/10
# Fold 5, Epoch 39/50, Train Loss: 0.013134, Val MAE: 0.021326, Val RMSE: 0.163721, Val R2: 0.846439
# No improvement. Patience: 9/10
# Fold 5, Epoch 40/50, Train Loss: 0.007709, Val MAE: 0.018507, Val RMSE: 0.132940, Val R2: 0.898753
# No improvement. Patience: 10/10
# Early stopping fold 5 at epoch 40.
# Fold 5 finished. Best epoch: 30, Best RMSE: 0.129036

# %%
results_df = pd.DataFrame(fold_results)

print(results_df)

print("MAE mean:", results_df["MAE"].mean())
print("MAE std:", results_df["MAE"].std())

print("RMSE mean:", results_df["RMSE"].mean())
print("RMSE std:", results_df["RMSE"].std())

print("R2 mean:", results_df["R2"].mean())
print("R2 std:", results_df["R2"].std())
# Out:
#    fold  best_epoch       MAE      RMSE        R2  epochs_run
# 0     1           6  0.059549  0.290260  0.810209          16
# 1     2          16  0.133839  0.395469  0.808325          26
# 2     3          38  0.013017  0.125838  0.910227          48
# 3     4          38  0.010496  0.075867  0.892799          48
# 4     5          30  0.018691  0.129036  0.904613          40
# MAE mean: 0.047118276
# MAE std: 0.05240998417139053
# RMSE mean: 0.20329419
# RMSE std: 0.1343929022550583
# R2 mean: 0.8652344
# R2 std: 0.05148132145404816

# %% [markdown]
# ## U-net model for downscaling

# %%
class SupervisedFloodDataset(Dataset):
    def __init__(self, X_full, y_full, patch_size=160, stride=None):
        self.X = X_full.astype("float32")
        self.y = y_full[np.newaxis, :, :].astype("float32")
        self.patch_size = patch_size
        self.stride = stride or patch_size
        self.samples = []

        _, height, width = self.X.shape
        for i in range(0, height - patch_size + 1, self.stride):
            for j in range(0, width - patch_size + 1, self.stride):
                y_patch = self.y[:, i:i + patch_size, j:j + patch_size]
                if np.isfinite(y_patch).sum() == 0:
                    continue
                self.samples.append((i, j))

        print("train_dataset length:", len(self.samples))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        i, j = self.samples[idx]
        X_patch = self.X[:, i:i + self.patch_size, j:j + self.patch_size]
        y_patch = self.y[:, i:i + self.patch_size, j:j + self.patch_size]
        return (
            torch.tensor(X_patch, dtype=torch.float32),
            torch.tensor(y_patch, dtype=torch.float32),
        )

# %%
PATCH_SIZE,STRIDE
# Out:
# (64, 32)

# %%
train_dataset = SupervisedFloodDataset(
    X_full=X_full,
    y_full=y_full,
    patch_size=PATCH_SIZE,
    stride=STRIDE,
)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
)

if len(train_dataset) == 0:
    raise ValueError("No valid supervised training patches were found. Check y_full coverage and PATCH_SIZE.")
# Out:
# train_dataset length: 137

# %%
in_channels = 6

model = UNet(in_channels=in_channels).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

train_loss_history = []

for epoch in range(EPOCHS):
    model.train()
    total_loss = 0.0
    valid_batches = 0

    for X_patch, y_patch in train_loader:
        X_patch = X_patch.to(device)
        y_patch = y_patch.to(device)

        pred = model(X_patch)

        loss1 = masked_mse_loss(pred, y_patch)
        if loss1 is None:
            continue

        loss2 = smoothness_loss(pred)
        loss = loss1 + SMOOTHNESS_WEIGHT * loss2

        if torch.isnan(loss):
            print("NaN loss detected")
            print("loss1:", loss1)
            print("loss2:", loss2)
            break

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        valid_batches += 1

    if valid_batches == 0:
        print(f"Epoch {epoch + 1}: no valid batches")
    else:
        epoch_loss = total_loss / valid_batches
        train_loss_history.append(epoch_loss)

        print(
            f"Epoch {epoch + 1}/{EPOCHS}, "
            f"Loss: {epoch_loss:.6f}"
        )

torch.save(model.state_dict(), "final_unet_all_data.pth")
print("Final model saved.")
# Out:
# Epoch 1/50, Loss: 0.160966
# Epoch 2/50, Loss: 0.095947
# Epoch 3/50, Loss: 0.077943
# Epoch 4/50, Loss: 0.056551
# Epoch 5/50, Loss: 0.051534
# Epoch 6/50, Loss: 0.045626
# Epoch 7/50, Loss: 0.030174
# Epoch 8/50, Loss: 0.031572
# Epoch 9/50, Loss: 0.040216
# Epoch 10/50, Loss: 0.029208
# Epoch 11/50, Loss: 0.015849
# Epoch 12/50, Loss: 0.029754
# Epoch 13/50, Loss: 0.023756
# Epoch 14/50, Loss: 0.018545
# Epoch 15/50, Loss: 0.025701
# Epoch 16/50, Loss: 0.022743
# Epoch 17/50, Loss: 0.013565
# Epoch 18/50, Loss: 0.034267
# Epoch 19/50, Loss: 0.011136
# Epoch 20/50, Loss: 0.010305
# Epoch 21/50, Loss: 0.015376
# Epoch 22/50, Loss: 0.011890
# Epoch 23/50, Loss: 0.010729
# Epoch 24/50, Loss: 0.007302
# Epoch 25/50, Loss: 0.007214
# Epoch 26/50, Loss: 0.013361
# Epoch 27/50, Loss: 0.007999
# Epoch 28/50, Loss: 0.010299
# Epoch 29/50, Loss: 0.007765
# Epoch 30/50, Loss: 0.009442
# Epoch 31/50, Loss: 0.004267
# Epoch 32/50, Loss: 0.004551
# Epoch 33/50, Loss: 0.007592
# Epoch 34/50, Loss: 0.006483
# Epoch 35/50, Loss: 0.006127
# Epoch 36/50, Loss: 0.010344
# Epoch 37/50, Loss: 0.009811
# Epoch 38/50, Loss: 0.019763
# Epoch 39/50, Loss: 0.009481
# Epoch 40/50, Loss: 0.005077
# Epoch 41/50, Loss: 0.006146
# Epoch 42/50, Loss: 0.005089
# Epoch 43/50, Loss: 0.004321
# Epoch 44/50, Loss: 0.005232
# Epoch 45/50, Loss: 0.003102
# Epoch 46/50, Loss: 0.002784
# Epoch 47/50, Loss: 0.005415
# Epoch 48/50, Loss: 0.005441
# Epoch 49/50, Loss: 0.003492
# Epoch 50/50, Loss: 0.003518
# Final model saved.

# %%
def predict_full_map_overlap(
    model,
    X_full,
    patch_size=PATCH_SIZE,
    stride=STRIDE,
    batch_size=4,
    device="cpu"
):
    model.eval()

    _, height, width = X_full.shape

    pad_h = max(patch_size - height, 0)
    pad_w = max(patch_size - width, 0)

    if height > patch_size:
        pad_h = (stride - (height - patch_size) % stride) % stride

    if width > patch_size:
        pad_w = (stride - (width - patch_size) % stride) % stride

    X_pad = np.pad(
        X_full,
        ((0, 0), (0, pad_h), (0, pad_w)),
        mode="constant",
        constant_values=0,
    )

    _, padded_height, padded_width = X_pad.shape

    pred_sum = np.zeros(
        (padded_height, padded_width),
        dtype="float32"
    )

    pred_count = np.zeros(
        (padded_height, padded_width),
        dtype="float32"
    )

    patches = []
    positions = []

    with torch.no_grad():

        for i in range(0, padded_height - patch_size + 1, stride):
            for j in range(0, padded_width - patch_size + 1, stride):

                patches.append(
                    X_pad[:, i:i + patch_size, j:j + patch_size]
                )
                positions.append((i, j))

                if len(patches) == batch_size:
                    batch = torch.tensor(
                        np.stack(patches),
                        dtype=torch.float32
                    ).to(device)

                    batch_pred = model(batch).cpu().numpy()[:, 0]

                    for pred_patch, (pi, pj) in zip(batch_pred, positions):
                        pred_sum[
                            pi:pi + patch_size,
                            pj:pj + patch_size
                        ] += pred_patch

                        pred_count[
                            pi:pi + patch_size,
                            pj:pj + patch_size
                        ] += 1

                    patches = []
                    positions = []

        if patches:
            batch = torch.tensor(
                np.stack(patches),
                dtype=torch.float32
            ).to(device)

            batch_pred = model(batch).cpu().numpy()[:, 0]

            for pred_patch, (pi, pj) in zip(batch_pred, positions):
                pred_sum[
                    pi:pi + patch_size,
                    pj:pj + patch_size
                ] += pred_patch

                pred_count[
                    pi:pi + patch_size,
                    pj:pj + patch_size
                ] += 1

    pred_pad = pred_sum / np.maximum(pred_count, 1)

    return pred_pad[:height, :width]

# %%
pred_full = predict_full_map_overlap(
    model=model,
    X_full=X_full,
    patch_size=PATCH_SIZE,
    stride=STRIDE,
    batch_size=BATCH_SIZE,
    device=device,
)

# %%
error_map = pred_full - y_full

fig, axes = plt.subplots(2, 2, figsize=(14, 12))
plots = [
    (water_01_up, "0.1 Degree Water Depth Resampled to 0.025", "turbo"),
    (pred_full, "U-Net Prediction", "turbo"),
    (water_025, "True 0.025 Degree Water Depth", "turbo"),
    (error_map, "Prediction Error", "coolwarm"),
]

for ax, (arr, title, cmap) in zip(axes.ravel(), plots):
    im = ax.imshow(arr, cmap=cmap)
    ax.set_title(title)
    ax.axis("off")
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()

# %%
import geopandas as gpd
import rasterio
from rasterio.features import geometry_mask
import numpy as np

texas_mask = geometry_mask(
    [texas_boundary],
    out_shape=pred_full.shape,
    transform=water_025_transform,
    invert=True
)

pred_full_tx = np.where(
    texas_mask,
    pred_full,
    np.nan
)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.imshow(pred_full_tx, cmap="turbo")
plt.colorbar()
plt.title("U-Net Prediction Clipped to Texas")
plt.axis("off")
plt.show()

# %%
profile = water_025_profile.copy()

profile.update(
    dtype="float32",
    count=1,
    nodata=-9999,
    compress="lzw"
)

pred_save = np.where(
    np.isfinite(pred_full_tx),
    pred_full_tx,
    -9999
).astype("float32")

with rasterio.open("pred_full_texas.tif", "w", **profile) as dst:
    dst.write(pred_save, 1)

print("Saved: pred_full_texas.tif")
# Out:
# WARNING:rasterio._env:CPLE_IllegalArg in pred_full_texas.tif: BLOCKXSIZE can only be used with TILED=YES
# Saved: pred_full_texas.tif
